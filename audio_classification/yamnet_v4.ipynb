# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv

import matplotlib.pyplot as plt
from IPython.display import Audio
from IPython.core.display import display
from scipy.io import wavfile
import scipy


# Preprocessing
from sklearn.preprocessing import MinMaxScaler
# from sklearn.cross_validation import KFold
from sklearn.model_selection import train_test_split, KFold

# Performance metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# LSTM
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Lambda, Conv2D, BatchNormalization
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Activation, MaxPool2D, Flatten, Dropout
from tensorflow.keras.losses import CategoricalCrossentropy

# import tensorflow_io as tfio
# Out:
# /var/folders/gp/1_dqbwsn08sbtf7s0k5q2lsc0000gn/T/ipykernel_73868/4222563939.py:9: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display

# %%
import os
import os
import sys
import shutil
import librosa
import pickle

# %%
CURR_DIR = os.getcwd()

# %% [markdown]
# # Utilities

# %%
DATA_DIR = os.path.join(CURR_DIR, "huge_collated_dataset")

# %% [markdown]
# ### Resample waveform to 16k

# %%
def ensure_sample_rate(original_sample_rate, waveform,
                       desired_sample_rate=16000):
  """Resample waveform if required."""
  if original_sample_rate != desired_sample_rate:
    desired_length = int(round(float(len(waveform)) /
                               original_sample_rate * desired_sample_rate))
    waveform = scipy.signal.resample(waveform, desired_length)
  return desired_sample_rate, waveform

# %% [markdown]
# ### Function to load audio files

# %%
@tf.function
def load_wavfile(filename):
    """ Load a WAV file, convert it to a float tensor, resample to 16 kHz single-channel audio. """
    file_contents = tf.io.read_file(filename)
    wav, sample_rate = tf.audio.decode_wav(
          file_contents,
          desired_channels=1)
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Happy

# %%
# wav_file_name = 'speech_whistling2.wav'
category = "happy"
wav_file_name = '2c9c46babe.wav'

file_path = os.path.join(DATA_DIR, category, wav_file_name)

sample_rate, wav_data = wavfile.read(file_path, 'rb')
sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

# Show some basic information about the audio.
duration = len(wav_data)/sample_rate
print(f'Sample rate: {sample_rate} Hz')
print(f'Total duration: {duration:.2f}s')
print(f'Size of the input: {len(wav_data)}')

# Listening to the wav file.
Audio(wav_data, rate=sample_rate)
plt.plot(wav_data)
# Out:
# Sample rate: 16000 Hz
# Total duration: 3.52s
# Size of the input: 56287
# /var/folders/gp/1_dqbwsn08sbtf7s0k5q2lsc0000gn/T/ipykernel_59475/788395808.py:7: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, wav_data = wavfile.read(file_path, 'rb')

# %% [markdown]
# ### Sad

# %%
# wav_file_name = 'speech_whistling2.wav'
category = "sad"
wav_file_name = '1ac2b3d011.wav'

file_path = os.path.join(DATA_DIR, category, wav_file_name)

sample_rate, wav_data = wavfile.read(file_path, 'rb')
sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

# Show some basic information about the audio.
duration = len(wav_data)/sample_rate
print(f'Sample rate: {sample_rate} Hz')
print(f'Total duration: {duration:.2f}s')
print(f'Size of the input: {len(wav_data)}')

# Listening to the wav file.
Audio(wav_data, rate=sample_rate)
plt.plot(wav_data)
# Out:
# Sample rate: 16000 Hz
# Total duration: 2.17s
# Size of the input: 34790

# %% [markdown]
# ### Neutral

# %%
# wav_file_name = 'speech_whistling2.wav'
category = "neutral"
wav_file_name = '3a49f17ceb.wav'

file_path = os.path.join(DATA_DIR, category, wav_file_name)

sample_rate, wav_data = wavfile.read(file_path, 'rb')
sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

# Show some basic information about the audio.
duration = len(wav_data)/sample_rate
print(f'Sample rate: {sample_rate} Hz')
print(f'Total duration: {duration:.2f}s')
print(f'Size of the input: {len(wav_data)}')

# Listening to the wav file.
Audio(wav_data, rate=sample_rate)
plt.plot(wav_data)
# Out:
# Sample rate: 16000 Hz
# Total duration: 2.11s
# Size of the input: 33717

# %% [markdown]
# ### Fear

# %%
# wav_file_name = 'speech_whistling2.wav'
category = "fear"
wav_file_name = '0ef63f4364.wav'

file_path = os.path.join(DATA_DIR, category, wav_file_name)

sample_rate, wav_data = wavfile.read(file_path, 'rb')
sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

# Show some basic information about the audio.
duration = len(wav_data)/sample_rate
print(f'Sample rate: {sample_rate} Hz')
print(f'Total duration: {duration:.2f}s')
print(f'Size of the input: {len(wav_data)}')

# Listening to the wav file.
Audio(wav_data, rate=sample_rate)
plt.plot(wav_data)
# Out:
# Sample rate: 16000 Hz
# Total duration: 1.74s
# Size of the input: 27816

# %% [markdown]
# # Recording the files

# %%
ext_to_category = {
    "SAD": "sadness",
    "ANG": "angry",
    "DIS": "disgust",
    "FEA": "fear",
    "HAP": "happy",
    "NEU": "neutral"
}

# %%
rows = []
for file in os.listdir(DATA_DIR):
    if file.startswith("."):
        continue

    file_path = os.path.join(DATA_DIR, file)        
    rel_file_path = os.path.relpath(file_path)

    tmp = rel_file_path.split("_")[2]
    category = ext_to_category[tmp]

    row = {
        "file": file,
        "file_path": rel_file_path, 
        "label": category
    }

    rows.append(row)


# categories

# %%
# rows = []

# for category in categories[:]:
#     CATEGORY_DIR = os.path.join(DATA_DIR, category)

#     for file in os.listdir(CATEGORY_DIR):
#         if file.startswith("."):
#             continue

#         file_path = os.path.join(CATEGORY_DIR, file)        
#         rel_file_path = os.path.relpath(file_path)

#         row = {
#             "file": file,
#             "file_path": rel_file_path, 
#             "label": category
#         }
    
#         rows.append(row)

# %%
df = pd.DataFrame(rows)

# %%
df.head()
# Out:
#                   file                  file_path    label
# 0  1022_ITS_ANG_XX.wav  Crema/1022_ITS_ANG_XX.wav    angry
# 1  1037_ITS_ANG_XX.wav  Crema/1037_ITS_ANG_XX.wav    angry
# 2  1060_ITS_NEU_XX.wav  Crema/1060_ITS_NEU_XX.wav  neutral
# 3  1075_ITS_NEU_XX.wav  Crema/1075_ITS_NEU_XX.wav  neutral
# 4  1073_IOM_DIS_XX.wav  Crema/1073_IOM_DIS_XX.wav  disgust

# %%
df.describe()
# Out:
#                        file                  file_path  label
# count                  7442                       7442   7442
# unique                 7442                       7442      6
# top     1022_ITS_ANG_XX.wav  Crema/1022_ITS_ANG_XX.wav  angry
# freq                      1                          1   1271

# %%
df.isna().sum()
# Out:
# file         0
# file_path    0
# label        0
# dtype: int64

# %%
# # Save datafram
# df.to_csv("crema_dataset_meta.csv", index=False)

# %% [markdown]
# # Data Preprocessing

# %%
waveform = wav_data / tf.int16.max

# %%
label_to_target = {
    "sad": 0,
    "fear": 1,
    "angry": 2,
    "neutral": 3, 
    "happy": 4
}

# label_to_target = {
#     "sadness": 0,
#     "fear": 1,
#     "angry": 2,
#     "disgust": 3,
#     "neutral": 4, 
#     "happy": 5
# }

# %%
# Read the meta data
df = pd.read_csv("huge_collated_dataset_meta.csv")
print(len(df))
df.head()
# Out:
# 8577
#                       file                                          file_path  \
# 0   happy_0_0_78_vesus.wav  huge_collated_dataset/happy/happy_0_0_78_vesus...
# 1  happy_5_2_124_vesus.wav  huge_collated_dataset/happy/happy_5_2_124_vesu...
# 2  happy_7_4_202_vesus.wav  huge_collated_dataset/happy/happy_7_4_202_vesu...
# 3   happy_4_4_38_vesus.wav  huge_collated_dataset/happy/happy_4_4_38_vesus...
# 4  happy_6_4_140_vesus.wav  huge_collated_dataset/happy/happy_6_4_140_vesu...
#
#    label
# 0  happy
# 1  happy
# 2  happy
# 3  happy
# 4  happy

# %%
df['label'] = df['label'].apply(lambda x: label_to_target[x])

# %%
df['label']
# Out:
# 0       4
# 1       4
# 2       4
# 3       4
# 4       4
#        ..
# 8572    2
# 8573    2
# 8574    2
# 8575    2
# 8576    2
# Name: label, Length: 8577, dtype: int64

# %%
df.isna().sum()
# Out:
# file         0
# file_path    0
# label        0
# target       0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(df['file_path'], df['label'], test_size=0.2, random_state=42)

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %%
# # Save train and test
# df_train.to_csv("crema_df_train.csv", index=False)
# df_test.to_csv("crema_df_test.csv", index=False)

# %% [markdown]
# ### Manual processing

# %%
def load_audio(file_path, label):
    # file_path_str = bytes.decode(file_path.numpy())
    # print(file_path_str)
    sample_rate, wav_data = wavfile.read(file_path, 'rb')
    sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

    # # Normalise wave data
    # wav_data = wav_data / tf.int16.max

    # Convert to tensor
    wav_data_tensor = tf.convert_to_tensor(wav_data, dtype=tf.float32)
    label_tensor = tf.convert_to_tensor(label, dtype=tf.int64)
    return (wav_data_tensor, label_tensor)

# %%
# Load the model.
yamnet_model = hub.load('https://tfhub.dev/google/yamnet/1')

# %%
def extract_embedding(wav_data, label):
  ''' run YAMNet to extract embedding from the wav data '''
  scores, embeddings, spectrogram = yamnet_model(wav_data)
  num_embeddings = tf.shape(embeddings)[0]
  return (embeddings,
            tf.repeat(label, num_embeddings))

# %%
# scores, embeddings, spectrogram = yamnet_model(wav_data)

# %%
train_ls = []

# %%
for file_path, label in list(zip(X_train, y_train)):
    wav_data_tensor, label_tensor = load_audio(file_path, label)
    train_ls.append((wav_data_tensor, label_tensor))
# Out:
# /var/folders/gp/1_dqbwsn08sbtf7s0k5q2lsc0000gn/T/ipykernel_73868/2950063737.py:4: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, wav_data = wavfile.read(file_path, 'rb')

# %%
train_embedding_tensor_ls = []

# %%
counter = 0
for wave, label in train_ls:
    try:
        scores, embeddings, spectrogram = yamnet_model(wave)
        for embedding in embeddings:
            train_embedding_tensor_ls.append((embedding, label))
    except Exception:
        print(counter, label)
    
    counter += 1
# Out:
# 461 tf.Tensor(1, shape=(), dtype=int64)

# %%
# train_wave_tensor_ds = tf.concat(train_ls, axis=0)

# %%
# # Save train_embedding_tensor_ls
# with open("train_embeeding_tensor_ls2.pkl", "wb") as file:
#     pickle.dump(train_embedding_tensor_ls, file)

# %%
# Load train_embedding_tensor_ls
with open("train_embeeding_tensor_ls2.pkl", "rb") as file:
    train_embedding_tensor_ls = pickle.load(file)

# %%
len(train_embedding_tensor_ls)
# Out:
# 22734

# %%
test_ls = []

# %%
for file_path, label in list(zip(X_test, y_test)):
    wav_data_tensor, label_tensor = load_audio(file_path, label)
    test_ls.append((wav_data_tensor, label_tensor))
# Out:
# /var/folders/gp/1_dqbwsn08sbtf7s0k5q2lsc0000gn/T/ipykernel_73868/2950063737.py:4: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, wav_data = wavfile.read(file_path, 'rb')

# %%
test_embedding_tensor_ls = []

# %%
for wave, label in test_ls:
    scores, embeddings, spectrogram = yamnet_model(wave)
    for embedding in embeddings:
        test_embedding_tensor_ls.append((embedding, label))

# %%
# # Save train_embedding_tensor_ls
# with open("test_embeeding_tensor_ls2.pkl", "wb") as file:
#     pickle.dump(test_embedding_tensor_ls, file)

# %%
# Load train_embedding_tensor_ls
with open("test_embeeding_tensor_ls2.pkl", "rb") as file:
    test_embedding_tensor_ls = pickle.load(file)

# %%
len(test_embedding_tensor_ls)
# Out:
# 5497

# %% [markdown]
# #### Convert to numpy

# %%
tf.concat(test_embedding_tensor_ls, axis=0)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb Cell 61 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb#Y254sZmlsZQ%3D%3D?line=0'>1</a> tf.concat(test_embedding_tensor_ls, axis=0)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1677, in concat(values, axis, name)
#    1673     ops.convert_to_tensor(
#    1674         axis, name="concat_dim",
#    1675         dtype=dtypes.int32).get_shape().assert_has_rank(0)
#    1676     return identity(values[0], name=name)
# -> 1677 return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1197, in concat_v2(values, axis, name)
#    1195   pass
#    1196 try:
# -> 1197   return concat_v2_eager_fallback(
#    1198       values, axis, name=name, ctx=_ctx)
#    1199 except _core._SymbolicException:
#    1200   pass  # Add nodes to the TensorFlow graph.
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1228, in concat_v2_eager_fallback(values, axis, name, ctx)
#    1224   raise TypeError(
#    1225       "Expected list for 'values' argument to "
#    1226       "'concat_v2' Op, not %r." % values)
#    1227 _attr_N = len(values)
# -> 1228 _attr_T, values = _execute.args_to_matching_eager(list(values), ctx, [])
#    1229 _attr_Tidx, (axis,) = _execute.args_to_matching_eager([axis], ctx, [_dtypes.int32, _dtypes.int64, ], _dtypes.int32)
#    1230 _inputs_flat = list(values) + [axis]
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:273, in args_to_matching_eager(l, ctx, allowed_dtypes, default_dtype)
#     270     tensor = None
#     272 if tensor is None:
# --> 273   tensor = ops.convert_to_tensor(
#     274       t, dtype, preferred_dtype=default_dtype, ctx=ctx)
#     276 ret.append(tensor)
#     277 if dtype is None:
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     161   with Trace(trace_name, **trace_kwargs):
#     162     return func(*args, **kwargs)
# --> 163 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1540, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1535       raise TypeError("convert_to_tensor did not convert to "
#    1536                       "the preferred dtype: %s vs %s " %
#    1537                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1539 if ret is None:
# -> 1540   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1542 if ret is NotImplemented:
#    1543   continue
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1525, in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1523 elif dtype != inferred_dtype:
#    1524   v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# -> 1525 return _autopacking_helper(v, dtype, name or "packed")
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1431, in _autopacking_helper(list_or_tuple, dtype, name)
#    1427 if context.executing_eagerly():
#    1428   # NOTE: Fast path when all the items are tensors, this doesn't do any type
#    1429   # checking.
#    1430   if all(isinstance(elem, core.Tensor) for elem in list_or_tuple):
# -> 1431     return gen_array_ops.pack(list_or_tuple, name=name)
#    1432 must_pack = False
#    1433 converted_elems = []
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:6380, in pack(values, axis, name)
#    6378   return _result
#    6379 except _core._NotOkStatusException as e:
# -> 6380   _ops.raise_from_not_ok_status(e, name)
#    6381 except _core._FallbackException:
#    6382   pass
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#    6860 message = e.message + (" name: " + name if name is not None else "")
#    6861 # pylint: disable=protected-access
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# InvalidArgumentError: cannot compute Pack as input #1(zero-based) was expected to be a float tensor but is a int64 tensor [Op:Pack] name: packed

# %%
temp = []

# %%
train_tensor = []
train_labels = []
for tensor, label in train_embedding_tensor_ls:
    # np_array = tensor.numpy()
    train_tensor.append(tensor)
    train_labels.append(label)

# %%
train_dataset = tf.data.Dataset.from_tensors((train_tensor, train_labels))

# %%
test_tensor = []
test_labels = []
for tensor, label in test_embedding_tensor_ls:
    # np_array = tensor.numpy()
    test_tensor.append(tensor)
    test_labels.append(label)

# %%
test_dataset = tf.data.Dataset.from_tensors((test_tensor, test_labels))

# %%
counter = 0 
for embedding, label in train_dataset:
    if counter > 5:
        break
    
    print(embedding.shape, label)

    counter += 1
# Out:
# (22734, 1024) tf.Tensor([0 0 0 ... 2 2 2], shape=(22734,), dtype=int64)

# %%
train_dataset
# Out:
# <TensorDataset shapes: ((28435, 1024), (28435,)), types: (tf.float32, tf.int64)>

# %% [markdown]
# # Training Model v2

# %%
len(train_tensor)
# Out:
# 22734

# %%
# class Model(tf.Module):
#     def __init__(self, name=None):
#         super().__init__(name=name)
#         self.dense1 = tf.keras.layers

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1024,), dtype=tf.float32,
                          name='input_embedding'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(5)
], name='my_model')

model.summary()
# Out:
# Model: "my_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_23 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_24 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dense_25 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dense_26 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 689,669
# Trainable params: 689,669
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer="adam",
                 metrics=['accuracy'])

early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                            patience=10,
                                            restore_best_weights=True)

save_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'model_4/model.epoch{epoch:02d}.hdf5',
    monitor ='val_loss',
    verbose = 1,
    save_best_only = True,
)

callbacks = [early_stop, save_model_checkpoint]

# %%
history = model.fit(train_dataset,
                       epochs=50,
                       validation_data=test_dataset,
                       callbacks=callbacks)
# Out:
# Epoch 1/50
# 1/1 [==============================] - 2s 2s/step - loss: 1.9552 - accuracy: 0.2592 - val_loss: 2.1870 - val_accuracy: 0.3196
#
# Epoch 00001: val_loss improved from inf to 2.18699, saving model to model_4/model.epoch01.hdf5
# Epoch 2/50
# 1/1 [==============================] - 1s 703ms/step - loss: 1.9535 - accuracy: 0.3408 - val_loss: 1.9479 - val_accuracy: 0.3362
#
# Epoch 00002: val_loss improved from 2.18699 to 1.94791, saving model to model_4/model.epoch02.hdf5
# Epoch 3/50
# 1/1 [==============================] - 1s 693ms/step - loss: 1.7780 - accuracy: 0.3588 - val_loss: 1.8462 - val_accuracy: 0.3405
#
# Epoch 00003: val_loss improved from 1.94791 to 1.84624, saving model to model_4/model.epoch03.hdf5
# Epoch 4/50
# 1/1 [==============================] - 1s 642ms/step - loss: 1.7880 - accuracy: 0.3665 - val_loss: 1.5588 - val_accuracy: 0.3744
#
# Epoch 00004: val_loss improved from 1.84624 to 1.55881, saving model to model_4/model.epoch04.hdf5
# Epoch 5/50
# 1/1 [==============================] - 1s 651ms/step - loss: 1.5041 - accuracy: 0.4096 - val_loss: 1.5757 - val_accuracy: 0.3547
#
# Epoch 00005: val_loss did not improve from 1.55881
# Epoch 6/50
# 1/1 [==============================] - 1s 622ms/step - loss: 1.5411 - accuracy: 0.3949 - val_loss: 1.6674 - val_accuracy: 0.3877
#
# Epoch 00006: val_loss did not improve from 1.55881
# Epoch 7/50
# 1/1 [==============================] - 1s 634ms/step - loss: 1.5674 - accuracy: 0.4231 - val_loss: 1.7188 - val_accuracy: 0.3960
#
# Epoch 00007: val_loss did not improve from 1.55881
# Epoch 8/50
# 1/1 [==============================] - 1s 653ms/step - loss: 1.5957 - accuracy: 0.4270 - val_loss: 1.6507 - val_accuracy: 0.3973
#
# Epoch 00008: val_loss did not improve from 1.55881
# Epoch 9/50
# 1/1 [==============================] - 1s 663ms/step - loss: 1.5465 - accuracy: 0.4285 - val_loss: 1.5121 - val_accuracy: 0.3939
#
# Epoch 00009: val_loss improved from 1.55881 to 1.51215, saving model to model_4/model.epoch09.hdf5
# Epoch 10/50
# 1/1 [==============================] - 1s 687ms/step - loss: 1.4552 - accuracy: 0.4286 - val_loss: 1.6225 - val_accuracy: 0.3755
#
# Epoch 00010: val_loss did not improve from 1.51215
# Epoch 11/50
# 1/1 [==============================] - 1s 716ms/step - loss: 1.6218 - accuracy: 0.4048 - val_loss: 1.4600 - val_accuracy: 0.3966
#
# Epoch 00011: val_loss improved from 1.51215 to 1.46002, saving model to model_4/model.epoch11.hdf5
# Epoch 12/50
# 1/1 [==============================] - 1s 750ms/step - loss: 1.4120 - accuracy: 0.4309 - val_loss: 1.5437 - val_accuracy: 0.4159
#
# Epoch 00012: val_loss did not improve from 1.46002
# Epoch 13/50
# 1/1 [==============================] - 1s 676ms/step - loss: 1.4566 - accuracy: 0.4466 - val_loss: 1.5583 - val_accuracy: 0.4195
#
# Epoch 00013: val_loss did not improve from 1.46002
# Epoch 14/50
# 1/1 [==============================] - 1s 641ms/step - loss: 1.4657 - accuracy: 0.4474 - val_loss: 1.5073 - val_accuracy: 0.4206
#
# Epoch 00014: val_loss did not improve from 1.46002
# Epoch 15/50
# 1/1 [==============================] - 1s 644ms/step - loss: 1.4303 - accuracy: 0.4489 - val_loss: 1.4142 - val_accuracy: 0.4244
#
# Epoch 00015: val_loss improved from 1.46002 to 1.41417, saving model to model_4/model.epoch15.hdf5
# Epoch 16/50
# 1/1 [==============================] - 1s 666ms/step - loss: 1.3672 - accuracy: 0.4540 - val_loss: 1.4594 - val_accuracy: 0.4208
#
# Epoch 00016: val_loss did not improve from 1.41417
# Epoch 17/50
# 1/1 [==============================] - 1s 628ms/step - loss: 1.4504 - accuracy: 0.4409 - val_loss: 1.3856 - val_accuracy: 0.4244
#
# Epoch 00017: val_loss improved from 1.41417 to 1.38563, saving model to model_4/model.epoch17.hdf5
# Epoch 18/50
# 1/1 [==============================] - 1s 634ms/step - loss: 1.3454 - accuracy: 0.4543 - val_loss: 1.4261 - val_accuracy: 0.4357
#
# Epoch 00018: val_loss did not improve from 1.38563
# Epoch 19/50
# 1/1 [==============================] - 1s 638ms/step - loss: 1.3624 - accuracy: 0.4671 - val_loss: 1.4335 - val_accuracy: 0.4370
#
# Epoch 00019: val_loss did not improve from 1.38563
# Epoch 20/50
# 1/1 [==============================] - 1s 662ms/step - loss: 1.3660 - accuracy: 0.4695 - val_loss: 1.3979 - val_accuracy: 0.4384
#
# Epoch 00020: val_loss did not improve from 1.38563
# Epoch 21/50
# 1/1 [==============================] - 1s 767ms/step - loss: 1.3420 - accuracy: 0.4713 - val_loss: 1.3337 - val_accuracy: 0.4435
#
# Epoch 00021: val_loss improved from 1.38563 to 1.33368, saving model to model_4/model.epoch21.hdf5
# Epoch 22/50
# 1/1 [==============================] - 1s 722ms/step - loss: 1.2995 - accuracy: 0.4740 - val_loss: 1.3425 - val_accuracy: 0.4404
#
# Epoch 00022: val_loss did not improve from 1.33368
# Epoch 23/50
# 1/1 [==============================] - 1s 743ms/step - loss: 1.3357 - accuracy: 0.4642 - val_loss: 1.3329 - val_accuracy: 0.4477
#
# Epoch 00023: val_loss improved from 1.33368 to 1.33292, saving model to model_4/model.epoch23.hdf5
# Epoch 24/50
# 1/1 [==============================] - 1s 741ms/step - loss: 1.2909 - accuracy: 0.4808 - val_loss: 1.3579 - val_accuracy: 0.4499
#
# Epoch 00024: val_loss did not improve from 1.33292
# Epoch 25/50
# 1/1 [==============================] - 1s 719ms/step - loss: 1.3037 - accuracy: 0.4850 - val_loss: 1.3467 - val_accuracy: 0.4550
#
# Epoch 00025: val_loss did not improve from 1.33292
# Epoch 26/50
# 1/1 [==============================] - 1s 720ms/step - loss: 1.2946 - accuracy: 0.4858 - val_loss: 1.2977 - val_accuracy: 0.4573
#
# Epoch 00026: val_loss improved from 1.33292 to 1.29771, saving model to model_4/model.epoch26.hdf5
# Epoch 27/50
# 1/1 [==============================] - 1s 737ms/step - loss: 1.2596 - accuracy: 0.4879 - val_loss: 1.3098 - val_accuracy: 0.4568
#
# Epoch 00027: val_loss did not improve from 1.29771
# Epoch 28/50
# 1/1 [==============================] - 1s 762ms/step - loss: 1.2882 - accuracy: 0.4824 - val_loss: 1.2773 - val_accuracy: 0.4617
#
# Epoch 00028: val_loss improved from 1.29771 to 1.27726, saving model to model_4/model.epoch28.hdf5
# Epoch 29/50
# 1/1 [==============================] - 1s 732ms/step - loss: 1.2424 - accuracy: 0.4933 - val_loss: 1.2939 - val_accuracy: 0.4603
#
# Epoch 00029: val_loss did not improve from 1.27726
# Epoch 30/50
# 1/1 [==============================] - 1s 724ms/step - loss: 1.2505 - accuracy: 0.4945 - val_loss: 1.2941 - val_accuracy: 0.4644
#
# Epoch 00030: val_loss did not improve from 1.27726
# Epoch 31/50
# 1/1 [==============================] - 1s 630ms/step - loss: 1.2478 - accuracy: 0.4944 - val_loss: 1.2714 - val_accuracy: 0.4626
#
# Epoch 00031: val_loss improved from 1.27726 to 1.27137, saving model to model_4/model.epoch31.hdf5
# Epoch 32/50
# 1/1 [==============================] - 1s 631ms/step - loss: 1.2315 - accuracy: 0.4971 - val_loss: 1.2479 - val_accuracy: 0.4677
#
# Epoch 00032: val_loss improved from 1.27137 to 1.24786, saving model to model_4/model.epoch32.hdf5
# Epoch 33/50
# 1/1 [==============================] - 1s 752ms/step - loss: 1.2212 - accuracy: 0.4944 - val_loss: 1.2440 - val_accuracy: 0.4723
#
# Epoch 00033: val_loss improved from 1.24786 to 1.24398, saving model to model_4/model.epoch33.hdf5
# Epoch 34/50
# 1/1 [==============================] - 1s 636ms/step - loss: 1.2236 - accuracy: 0.4912 - val_loss: 1.2491 - val_accuracy: 0.4713
#
# Epoch 00034: val_loss did not improve from 1.24398
# Epoch 35/50
# 1/1 [==============================] - 1s 662ms/step - loss: 1.2151 - accuracy: 0.5013 - val_loss: 1.2532 - val_accuracy: 0.4726
#
# Epoch 00035: val_loss did not improve from 1.24398
# Epoch 36/50
# 1/1 [==============================] - 1s 642ms/step - loss: 1.2157 - accuracy: 0.5039 - val_loss: 1.2333 - val_accuracy: 0.4768
#
# Epoch 00036: val_loss improved from 1.24398 to 1.23325, saving model to model_4/model.epoch36.hdf5
# Epoch 37/50
# 1/1 [==============================] - 1s 659ms/step - loss: 1.2003 - accuracy: 0.5054 - val_loss: 1.2584 - val_accuracy: 0.4677
#
# Epoch 00037: val_loss did not improve from 1.23325
# Epoch 38/50
# 1/1 [==============================] - 2s 2s/step - loss: 1.2293 - accuracy: 0.4963 - val_loss: 1.2533 - val_accuracy: 0.4748
#
# Epoch 00038: val_loss did not improve from 1.23325
# Epoch 39/50
# 1/1 [==============================] - 1s 685ms/step - loss: 1.2068 - accuracy: 0.5079 - val_loss: 1.2653 - val_accuracy: 0.4808
#
# Epoch 00039: val_loss did not improve from 1.23325
# Epoch 40/50
# 1/1 [==============================] - 1s 652ms/step - loss: 1.2156 - accuracy: 0.5107 - val_loss: 1.2554 - val_accuracy: 0.4801
#
# Epoch 00040: val_loss did not improve from 1.23325
# Epoch 41/50
# 1/1 [==============================] - 1s 667ms/step - loss: 1.2104 - accuracy: 0.5094 - val_loss: 1.2262 - val_accuracy: 0.4855
#
# Epoch 00041: val_loss improved from 1.23325 to 1.22622, saving model to model_4/model.epoch41.hdf5
# Epoch 42/50
# 1/1 [==============================] - 1s 726ms/step - loss: 1.1890 - accuracy: 0.5135 - val_loss: 1.2524 - val_accuracy: 0.4741
#
# Epoch 00042: val_loss did not improve from 1.22622
# Epoch 43/50
# 1/1 [==============================] - 1s 643ms/step - loss: 1.2200 - accuracy: 0.5037 - val_loss: 1.2252 - val_accuracy: 0.4792
#
# Epoch 00043: val_loss improved from 1.22622 to 1.22520, saving model to model_4/model.epoch43.hdf5
# Epoch 44/50
# 1/1 [==============================] - 1s 631ms/step - loss: 1.1873 - accuracy: 0.5120 - val_loss: 1.2413 - val_accuracy: 0.4844
#
# Epoch 00044: val_loss did not improve from 1.22520
# Epoch 45/50
# 1/1 [==============================] - 1s 637ms/step - loss: 1.1944 - accuracy: 0.5166 - val_loss: 1.2482 - val_accuracy: 0.4870
#
# Epoch 00045: val_loss did not improve from 1.22520
# Epoch 46/50
# 1/1 [==============================] - 1s 629ms/step - loss: 1.1982 - accuracy: 0.5184 - val_loss: 1.2359 - val_accuracy: 0.4852
#
# Epoch 00046: val_loss did not improve from 1.22520
# Epoch 47/50
# 1/1 [==============================] - 1s 641ms/step - loss: 1.1876 - accuracy: 0.5201 - val_loss: 1.2426 - val_accuracy: 0.4832
#
# Epoch 00047: val_loss did not improve from 1.22520
# Epoch 48/50
# 1/1 [==============================] - 1s 629ms/step - loss: 1.1964 - accuracy: 0.5153 - val_loss: 1.2319 - val_accuracy: 0.4881
#
# Epoch 00048: val_loss did not improve from 1.22520
# Epoch 49/50
# 1/1 [==============================] - 1s 661ms/step - loss: 1.1817 - accuracy: 0.5217 - val_loss: 1.2375 - val_accuracy: 0.4903
#
# Epoch 00049: val_loss did not improve from 1.22520
# Epoch 50/50
# 1/1 [==============================] - 1s 940ms/step - loss: 1.1848 - accuracy: 0.5250 - val_loss: 1.2263 - val_accuracy: 0.4890
#
# Epoch 00050: val_loss did not improve from 1.22520

# %%
df_history = pd.DataFrame(history.history)

# %%
# # Save training
# df_history.to_csv("model_4/df_history.csv", index=False)

# %% [markdown]
# # Training MOdel v1

# %%
# train_wave_tensor_ds = tf.concat(train_ls, axis=0)
# Out:
# ---------------------------------------------------------------------------
#
# InvalidArgumentError                      Traceback (most recent call last)
#
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb Cell 42 in <cell line: 1>()
#
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb#Y144sZmlsZQ%3D%3D?line=0'>1</a> train_wave_tensor_ds = tf.concat(train_ls, axis=0)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#
#     200 try:
#
# --> 201   return target(*args, **kwargs)
#
#     202 except (TypeError, ValueError):
#
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#
#     205   result = dispatch(wrapper, args, kwargs)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1677, in concat(values, axis, name)
#
#    1673     ops.convert_to_tensor(
#
#    1674         axis, name="concat_dim",
#
#    1675         dtype=dtypes.int32).get_shape().assert_has_rank(0)
#
#    1676     return identity(values[0], name=name)
#
# -> 1677 return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1197, in concat_v2(values, axis, name)
#
#    1195   pass
#
#    1196 try:
#
# -> 1197   return concat_v2_eager_fallback(
#
#    1198       values, axis, name=name, ctx=_ctx)
#
#    1199 except _core._SymbolicException:
#
#    1200   pass  # Add nodes to the TensorFlow graph.
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1228, in concat_v2_eager_fallback(values, axis, name, ctx)
#
#    1224   raise TypeError(
#
#    1225       "Expected list for 'values' argument to "
#
#    1226       "'concat_v2' Op, not %r." % values)
#
#    1227 _attr_N = len(values)
#
# -> 1228 _attr_T, values = _execute.args_to_matching_eager(list(values), ctx, [])
#
#    1229 _attr_Tidx, (axis,) = _execute.args_to_matching_eager([axis], ctx, [_dtypes.int32, _dtypes.int64, ], _dtypes.int32)
#
#    1230 _inputs_flat = list(values) + [axis]
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:273, in args_to_matching_eager(l, ctx, allowed_dtypes, default_dtype)
#
#     270     tensor = None
#
#     272 if tensor is None:
#
# --> 273   tensor = ops.convert_to_tensor(
#
#     274       t, dtype, preferred_dtype=default_dtype, ctx=ctx)
#
#     276 ret.append(tensor)
#
#     277 if dtype is None:
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#
#     161   with Trace(trace_name, **trace_kwargs):
#
#     162     return func(*args, **kwargs)
#
# --> 163 return func(*args, **kwargs)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1540, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#
#    1535       raise TypeError("convert_to_tensor did not convert to "
#
#    1536                       "the preferred dtype: %s vs %s " %
#
#    1537                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#
#    1539 if ret is None:
#
# -> 1540   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#
#    1542 if ret is NotImplemented:
#
#    1543   continue
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1525, in _autopacking_conversion_function(v, dtype, name, as_ref)
#
#    1523 elif dtype != inferred_dtype:
#
#    1524   v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
#
# -> 1525 return _autopacking_helper(v, dtype, name or "packed")
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1431, in _autopacking_helper(list_or_tuple, dtype, name)
#
#    1427 if context.executing_eagerly():
#
#    1428   # NOTE: Fast path when all the items are tensors, this doesn't do any type
#
#    1429   # checking.
#
#    1430   if all(isinstance(elem, core.Tensor) for elem in list_or_tuple):
#
# -> 1431     return gen_array_ops.pack(list_or_tuple, name=name)
#
#    1432 must_pack = False
#
#    1433 converted_elems = []
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:6380, in pack(values, axis, name)
#
#    6378   return _result
#
#    6379 except _core._NotOkStatusException as e:
#
# -> 6380   _ops.raise_from_not_ok_status(e, name)
#
#    6381 except _core._FallbackException:
#
#    6382   pass
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#
#    6860 message = e.message + (" name: " + name if name is not None else "")
#
#    6861 # pylint: disable=protected-access
#
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
#
#
# File <string>:3, in raise_from(value, from_value)
#
#
#
# InvalidArgumentError: cannot compute Pack as input #1(zero-based) was expected to be a float tensor but is a int64 tensor [Op:Pack] name: packed

# %%
# Save train_embedding_tensor_ls
with open("train_embeeding_tensor_ls.pkl", "wb") as file:
    pickle.dump(train_embedding_tensor_ls, file)

# %%
tf.convert_to_tensor(train_ls)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb Cell 44 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb#Y161sZmlsZQ%3D%3D?line=0'>1</a> tf.convert_to_tensor(train_ls)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1404, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1340 @tf_export("convert_to_tensor", v1=[])
#    1341 @dispatch.add_dispatch_support
#    1342 def convert_to_tensor_v2_with_dispatch(
#    1343     value, dtype=None, dtype_hint=None, name=None):
#    1344   """Converts the given `value` to a `Tensor`.
#    1345
#    1346   This function converts Python objects of various types to `Tensor`
#    (...)
#    1402     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1403   """
# -> 1404   return convert_to_tensor_v2(
#    1405       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1410, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1408 def convert_to_tensor_v2(value, dtype=None, dtype_hint=None, name=None):
#    1409   """Converts the given `value` to a `Tensor`."""
# -> 1410   return convert_to_tensor(
#    1411       value=value,
#    1412       dtype=dtype,
#    1413       name=name,
#    1414       preferred_dtype=dtype_hint,
#    1415       as_ref=False)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     161   with Trace(trace_name, **trace_kwargs):
#     162     return func(*args, **kwargs)
# --> 163 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1540, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1535       raise TypeError("convert_to_tensor did not convert to "
#    1536                       "the preferred dtype: %s vs %s " %
#    1537                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1539 if ret is None:
# -> 1540   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1542 if ret is NotImplemented:
#    1543   continue
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1525, in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1523 elif dtype != inferred_dtype:
#    1524   v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# -> 1525 return _autopacking_helper(v, dtype, name or "packed")
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1444, in _autopacking_helper(list_or_tuple, dtype, name)
#    1442   must_pack = True
#    1443 elif isinstance(elem, (list, tuple)):
# -> 1444   converted_elem = _autopacking_helper(elem, dtype, str(i))
#    1445   if isinstance(converted_elem, core.Tensor):
#    1446     must_pack = True
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1431, in _autopacking_helper(list_or_tuple, dtype, name)
#    1427 if context.executing_eagerly():
#    1428   # NOTE: Fast path when all the items are tensors, this doesn't do any type
#    1429   # checking.
#    1430   if all(isinstance(elem, core.Tensor) for elem in list_or_tuple):
# -> 1431     return gen_array_ops.pack(list_or_tuple, name=name)
#    1432 must_pack = False
#    1433 converted_elems = []
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:6380, in pack(values, axis, name)
#    6378   return _result
#    6379 except _core._NotOkStatusException as e:
# -> 6380   _ops.raise_from_not_ok_status(e, name)
#    6381 except _core._FallbackException:
#    6382   pass
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#    6860 message = e.message + (" name: " + name if name is not None else "")
#    6861 # pylint: disable=protected-access
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# InvalidArgumentError: cannot compute Pack as input #1(zero-based) was expected to be a float tensor but is a int64 tensor [Op:Pack] name: 0

# %%
test_ls = []

# %%
for file_path, label in list(zip(X_train, y_train)):
    wav_data_tensor, label_tensor = load_audio(file_path, label)
    train_ls.append((wav_data_tensor, label_tensor))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb Cell 86 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=0'>1</a> for file_path, label in list(zip(X_train, y_train)):
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=1'>2</a>     wav_data_tensor, label_tensor = load_audio(file_path, label)
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=2'>3</a>     train_ls.append((wav_data_tensor, label_tensor))
#
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb Cell 86 in load_audio(file_path, label)
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=2'>3</a> def load_audio(file_path, label):
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=3'>4</a>     file_path_str = bytes.decode(file_path.numpy())
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=4'>5</a>     print(file_path_str, label)
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=5'>6</a>     sample_rate, wav_data = wavfile.read(file_path_str, 'rb')
#
# AttributeError: 'str' object has no attribute 'numpy'

# %%
train_wave_tensor_ds = tf.concat(train_ls, axis=0)
# Out:
# ---------------------------------------------------------------------------
#
# InvalidArgumentError                      Traceback (most recent call last)
#
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb Cell 42 in <cell line: 1>()
#
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb#Y144sZmlsZQ%3D%3D?line=0'>1</a> train_wave_tensor_ds = tf.concat(train_ls, axis=0)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#
#     200 try:
#
# --> 201   return target(*args, **kwargs)
#
#     202 except (TypeError, ValueError):
#
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#
#     205   result = dispatch(wrapper, args, kwargs)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1677, in concat(values, axis, name)
#
#    1673     ops.convert_to_tensor(
#
#    1674         axis, name="concat_dim",
#
#    1675         dtype=dtypes.int32).get_shape().assert_has_rank(0)
#
#    1676     return identity(values[0], name=name)
#
# -> 1677 return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1193, in concat_v2(values, axis, name)
#
#    1191   return _result
#
#    1192 except _core._NotOkStatusException as e:
#
# -> 1193   _ops.raise_from_not_ok_status(e, name)
#
#    1194 except _core._FallbackException:
#
#    1195   pass
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#
#    6860 message = e.message + (" name: " + name if name is not None else "")
#
#    6861 # pylint: disable=protected-access
#
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
#
#
# File <string>:3, in raise_from(value, from_value)
#
#
#
# InvalidArgumentError: OpKernel 'ConcatV2' has constraint on attr 'T' not in NodeDef '[N=0, Tidx=DT_INT32]', KernelDef: 'op: "ConcatV2" device_type: "CPU" constraint { name: "T" allowed_values { list { type: DT_UINT64 } } } host_memory_arg: "axis"' [Op:ConcatV2] name: concat

# %%
# Save wave 
with open("train_wave_tensor", "wb") as file:
    pickle.dump(train_ls, file)

# %%
train_ls[2][1].numpy()
# Out:
# 2

# %%
# # Save the train and test set
# df_train = pd.concat([X_train, y_train], axis=1)
# print(df_train.head())

# df_train.to_csv("df_train.csv", index=False)

# df_test = pd.concat([X_test, y_test], axis=1)
# print(df_test.head())

# df_test.to_csv("df_test.csv", index=False)

# %%
wav1 = tf.convert_to_tensor(wav_data)
wav2 = tf.convert_to_tensor(wav_data)

# %%
ls = [wav1, wav2]

# %%
waves = tf.stack(ls)

# %%
waves.shape
# Out:
# TensorShape([2, 27520])

# %%
X_train
# Out:
# 2087      huge_collated_dataset/sad/sad_2_5_174_vesus.wav
# 5848    huge_collated_dataset/neutral/neutral_5_5_108_...
# 8532    huge_collated_dataset/angry/angry_7_6_78_vesus...
# 96      huge_collated_dataset/happy/happy_4_4_206_vesu...
# 5751    huge_collated_dataset/neutral/neutral_9_6_33_v...
#                               ...
# 5734    huge_collated_dataset/neutral/neutral_1_3_229_...
# 5191    huge_collated_dataset/neutral/neutral_5_5_85_v...
# 5390    huge_collated_dataset/neutral/neutral_8_1_145_...
# 860     huge_collated_dataset/happy/happy_2_2_143_vesu...
# 7270    huge_collated_dataset/angry/angry_4_1_92_vesus...
# Name: file_path, Length: 6861, dtype: object

# %% [markdown]
# # With Tensor Slices Pipeline

# %%
label_to_target = {
    "sad": 0,
    "fear": 1,
    "angry": 2,
    "neutral": 3, 
    "happy": 4
}

# label_to_target = {
#     "sadness": 0,
#     "fear": 1,
#     "angry": 2,
#     "disgust": 3,
#     "neutral": 4, 
#     "happy": 5
# }

# %%
df_train = pd.read_csv("df_train.csv")
df_test = pd.read_csv("df_test.csv")

# %%
X_train = df_train['file_path'][:]
y_train = df_train['label'][:].apply(lambda x: label_to_target[x])
X_test = df_test['file_path']
y_test = df_test['label'].apply(lambda x: label_to_target[x])

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds.element_spec
# Out:
# (TensorSpec(shape=(), dtype=tf.string, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test_ds.element_spec
# Out:
# (TensorSpec(shape=(), dtype=tf.string, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
# Helper load audio function
# @tf.function
def load_audio(file_path, label):
    file_path_str = bytes.decode(file_path.numpy())
    print(file_path_str, label)
    # sample_rate, wav_data = wavfile.read(file_path_str, 'rb')
    # sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

    sig, sr = librosa.load(file_path_str)
    wav_data = librosa.resample(sig, orig_sr=sr, target_sr=16000)

    # # Normalise wave data
    # wav_data = wav_data / tf.int16.max

    # Convert to tensor
    wav_data_tensor = tf.convert_to_tensor(wav_data, dtype=tf.float32)
    return (wav_data_tensor, label)

# %%
# train_audio_ds = train_ds.map(load_audio)

# %%
train_audio_ds = train_ds.map(lambda x, y: tf.py_function(load_audio, [x, y], [tf.float32, tf.int64]))
train_audio_ds
# Out:
# <MapDataset shapes: (<unknown>, <unknown>), types: (tf.float32, tf.int64)>

# %%
train_audio_ds.element_spec
# Out:
# (TensorSpec(shape=<unknown>, dtype=tf.float32, name=None),
#  TensorSpec(shape=<unknown>, dtype=tf.int64, name=None))

# %%
test_audio_ds = test_ds.map(lambda x, y: tf.py_function(load_audio, [x, y], [tf.float32, tf.int64]))
test_audio_ds
# Out:
# <MapDataset shapes: (<unknown>, <unknown>), types: (tf.float32, tf.int64)>

# %%
test_audio_ds.element_spec
# Out:
# (TensorSpec(shape=<unknown>, dtype=tf.float32, name=None),
#  TensorSpec(shape=<unknown>, dtype=tf.int64, name=None))

# %%
# for wave, target in train_audio_ds:
#     print(wave[:5])

# %% [markdown]
# # Transfer learning with YAMNet

# %%
# Load the model.
yamnet_model = hub.load('https://tfhub.dev/google/yamnet/1')
# Out:
# 2023-04-07 03:08:23.134326: W tensorflow/core/kernels/data/cache_dataset_ops.cc:757] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
def extract_embedding(wav_data, label):
  ''' run YAMNet to extract embedding from the wav data '''
  scores, embeddings, spectrogram = yamnet_model(wav_data)
  num_embeddings = tf.shape(embeddings)[0]
  return (embeddings,
            tf.repeat(label, num_embeddings))

# %%
main_ds = train_audio_ds.map(extract_embedding).unbatch()
main_ds.element_spec
# Out:
# (TensorSpec(shape=(1024,), dtype=tf.float32, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
val_ds = test_audio_ds.map(extract_embedding).unbatch()
val_ds.element_spec
# Out:
# (TensorSpec(shape=(1024,), dtype=tf.float32, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
# # Save the main_ds
# tf.data.experimental.save(main_ds, "./main_ds")

# # Save the val_ds
# tf.data.experimental.save(val_ds, "./val_ds")

# %%
main_train_ds = main_ds.cache().batch(32).prefetch(tf.data.AUTOTUNE)
val_train_ds = val_ds.cache().batch(32).prefetch(tf.data.AUTOTUNE)
# test_ds = test_ds.cache().batch(32).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # Training the Model

# %%
# class Model(tf.Module):
#     def __init__(self, name=None):
#         super().__init__(name=name)
#         self.dense1 = tf.keras.layers

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1024), dtype=tf.float32,
                          name='input_embedding'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(5)
], name='my_model')

model.summary()
# Out:
# Model: "my_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_20 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_21 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_22 (Dense)             (None, 5)                 645
# =================================================================
# Total params: 591,109
# Trainable params: 591,109
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                 optimizer="adam",
                 metrics=['accuracy'])

early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                            patience=8,
                                            restore_best_weights=True)

save_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'model_3/model.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5',
    monitor ='val_loss',
    verbose = 1,
    save_best_only = True,
)

callbacks = [early_stop, save_model_checkpoint]

# %%
history = model.fit(main_train_ds,
                       epochs=50,
                       validation_data=val_train_ds,
                       callbacks=callbacks)
# Out:
# Epoch 1/50
# huge_collated_dataset/sad/sad_2_5_174_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_5_5_108_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_7_6_78_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_4_4_206_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_9_6_33_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_3_0_202_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_1_2_26_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/sad/74be7612c4.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_9_4_216_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_4_4_89_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_7_1_6_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
#       1/Unknown - 2s 2s/step - loss: 6.0095 - accuracy: 0.2812huge_collated_dataset/neutral/neutral_3_3_171_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_6_4_229_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_1_5_119_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_tess1826.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_1_5_99_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_1_3_164_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_4_0_149_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_5_2_13_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_1_5_123_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_2_5_175_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_4_5_34_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_4_1_61_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
#       2/Unknown - 3s 1s/step - loss: 5.0588 - accuracy: 0.2969huge_collated_dataset/fear/fear_0_2_28_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_0_1_250_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_1_2_83_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_3_4_99_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_3_3_97_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_0_3_201_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_0_0_229_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_tess29.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_0_3_221_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_0_1_107_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
#       3/Unknown - 4s 1s/step - loss: 4.8607 - accuracy: 0.3021huge_collated_dataset/angry/angry_2_0_65_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_0_0_41_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/fear/441a0729a0.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_0_1_171_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_4_1_167_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_1_1_176_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/angry/1582eaecce.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/fear/1c937329b1.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/angry/d0172c3eb5.wav tf.Tensor(2, shape=(), dtype=int64)
#       4/Unknown - 6s 1s/step - loss: 5.0383 - accuracy: 0.2871huge_collated_dataset/neutral/neutral_0_3_124_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_3_0_8_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_1_1_42_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_9_0_78_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_6_4_216_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_7_6_87_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/fear/dbfd9bfbd2.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_8_1_23_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_4_1_49_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_4_5_217_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_9_0_243_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_6_4_197_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
#       5/Unknown - 7s 1s/step - loss: 5.2908 - accuracy: 0.2759huge_collated_dataset/neutral/neutral_5_5_64_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_2_0_212_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_3_1_220_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_1_1_132_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_3_4_27_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_6_5_223_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_6_1_58_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_2_1_54_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/sad/1ac2b3d011.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/fear/78a0dc6b94.wav tf.Tensor(1, shape=(), dtype=int64)
#       6/Unknown - 8s 1s/step - loss: 5.4585 - accuracy: 0.2681huge_collated_dataset/angry/angry_7_6_93_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/fear/129e52239a.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/fear/20d11f83df.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_2_1_104_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_1_3_56_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_3_0_150_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_0_4_32_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_8_4_224_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_3_3_194_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
#       7/Unknown - 10s 1s/step - loss: 5.5202 - accuracy: 0.2598huge_collated_dataset/neutral/neutral_8_1_146_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_3_1_62_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/angry/bc075f9f8d.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/fear/1dbe5d0c63.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_7_4_16_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_0_1_152_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_5_2_65_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_0_0_87_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_6_1_249_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_5_5_175_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
#       8/Unknown - 11s 1s/step - loss: 5.5189 - accuracy: 0.2561huge_collated_dataset/sad/sad_3_1_61_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_6_4_144_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_8_1_20_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_1_2_68_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_0_2_109_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_6_1_68_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_0_2_232_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_0_0_223_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_2_2_171_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_1_5_82_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/fear/348f779695.wav tf.Tensor(1, shape=(), dtype=int64)
#       9/Unknown - 12s 1s/step - loss: 5.4661 - accuracy: 0.2551huge_collated_dataset/neutral/neutral_1_3_238_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_4_1_44_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_3_0_67_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_2_5_107_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_ravdess377.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_5_0_46_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_7_1_87_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_tess1978.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_0_0_55_vesus.wav tf.Tensor(4, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_4_5_20_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
#      10/Unknown - 14s 1s/step - loss: 5.4170 - accuracy: 0.2536huge_collated_dataset/fear/fear_crema1491.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_5_5_244_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_4_3_182_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/fear/2f2d7bd4d2.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/sad/sad_2_5_160_vesus.wav tf.Tensor(0, shape=(), dtype=int64)
# huge_collated_dataset/fear/c368566b2b.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/neutral/neutral_4_0_67_vesus.wav tf.Tensor(3, shape=(), dtype=int64)
# huge_collated_dataset/fear/fear_0_2_133_vesus.wav tf.Tensor(1, shape=(), dtype=int64)
# huge_collated_dataset/angry/angry_3_4_1_vesus.wav tf.Tensor(2, shape=(), dtype=int64)
#      11/Unknown - 15s 1s/step - loss: 5.3466 - accuracy: 0.2523huge_collated_dataset/angry/37eefe1f31.wav tf.Tensor(2, shape=(), dtype=int64)
# huge_collated_dataset/happy/happy_2_2
50
# 711/711 [==============================] - 3s 4ms/step - loss: 4.6024 - accuracy: 0.2659 - val_loss: 4.6557 - val_accuracy: 0.2594
#
# Epoch 00003: val_loss did not improve from 4.65566
# Epoch 4/50
# 711/711 [==============================] - 3s 4ms/step - loss: 4.6024 - accuracy: 0.2659 - val_loss: 4.6557 - val_accuracy: 0.2594
#
# Epoch 00004: val_loss did not improve from 4.65566
# Epoch 5/50
# 711/711 [==============================] - 3s 4ms/step - loss: 4.6024 - accuracy: 0.2659 - val_loss: 4.6557 - val_accuracy: 0.2594
#
# Epoch 00005: val_loss did not improve from 4.65566
# Epoch 6/50
# 711/711 [==============================] - 3s 4ms/step - loss: 4.6024 - accuracy: 0.2659 - val_loss: 4.6557 - val_accuracy: 0.2594
#
# Epoch 00006: val_loss did not improve from 4.65566
# Epoch 7/50
# 711/711 [==============================] - 3s 4ms/step - loss: 4.6024 - accuracy: 0.2659 - val_loss: 4.6557 - val_accuracy: 0.2594
#
# Epoch 00007: val_loss did not improve from 4.65566
# Epoch 8/50
# 711/711 [==============================] - 3s 4ms/step - loss: 4.6024 - accuracy: 0.2659 - val_loss: 4.6557 - val_accuracy: 0.2594
#
# Epoch 00008: val_loss did not improve from 4.65566
# Epoch 9/50
# 711/711 [==============================] - 3s 4ms/step - loss: 4.6024 - accuracy: 0.2659 - val_loss: 4.6557 - val_accuracy: 0.2594
#
# Epoch 00009: val_loss did not improve from 4.65566
# Epoch 10/50
# 711/711 [==============================] - 3s 5ms/step - loss: 4.6024 - accuracy: 0.2659 - val_loss: 4.6557 - val_accuracy: 0.2594
#
# Epoch 00010: val_loss did not improve from 4.65566

# %% [markdown]
# # Saving the Model

# %%
class ReduceMeanLayer(tf.keras.layers.Layer):
  def __init__(self, axis=0, **kwargs):
    super(ReduceMeanLayer, self).__init__(**kwargs)
    self.axis = axis

  def call(self, input):
    return tf.math.reduce_mean(input, axis=self.axis)

# %%
# Run the model, check the output.
scores, embeddings, spectrogram = model(wave_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v1.ipynb Cell 44 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v1.ipynb#Y111sZmlsZQ%3D%3D?line=0'>1</a> # Run the model, check the output.
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v1.ipynb#Y111sZmlsZQ%3D%3D?line=1'>2</a> scores, embeddings, spectrogram = model(wave_data)
#
# NameError: name 'wave_data' is not defined

# %%
# Run the model, check the output.
scores, embeddings, spectrogram = model(waveform)
# Out:
# 2023-04-06 19:28:21.324701: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)

# %%
embeddings
# Out:
# <tf.Tensor: shape=(3, 1024), dtype=float32, numpy=
# array([[2.175924  , 0.3591828 , 0.5648943 , ..., 0.34278473, 2.2839918 ,
#         3.6191835 ],
#        [2.3264675 , 0.41704032, 0.45783436, ..., 0.33244064, 2.3892274 ,
#         3.5955532 ],
#        [2.0903363 , 0.34951845, 0.65777   , ..., 0.35120144, 2.218155  ,
#         3.730153  ]], dtype=float32)>

# %%
embeddings
# Out:
# <tf.Tensor: shape=(3, 1024), dtype=float32, numpy=
# array([[2.175924  , 0.3591828 , 0.5648943 , ..., 0.34278473, 2.2839918 ,
#         3.6191835 ],
#        [2.3264675 , 0.41704032, 0.45783436, ..., 0.33244064, 2.3892274 ,
#         3.5955532 ],
#        [2.0903363 , 0.34951845, 0.65777   , ..., 0.35120144, 2.218155  ,
#         3.730153  ]], dtype=float32)>

# %% [markdown]
# # Visualisation

# %%
plt.figure(figsize=(10, 6))

# Plot the waveform.
plt.subplot(3, 1, 1)
plt.plot(waveform)
plt.xlim([0, len(waveform)])

# Plot the log-mel spectrogram (returned by the model).
plt.subplot(3, 1, 2)
plt.imshow(spectrogram_np.T, aspect='auto', interpolation='nearest', origin='lower')

# Plot and label the model output scores for the top-scoring classes.
mean_scores = np.mean(scores, axis=0)
top_n = 10
top_class_indices = np.argsort(mean_scores)[::-1][:top_n]
plt.subplot(3, 1, 3)
plt.imshow(scores_np[:, top_class_indices].T, aspect='auto', interpolation='nearest', cmap='gray_r')

# patch_padding = (PATCH_WINDOW_SECONDS / 2) / PATCH_HOP_SECONDS
# values from the model documentation
patch_padding = (0.025 / 2) / 0.01
plt.xlim([-patch_padding-0.5, scores.shape[0] + patch_padding-0.5])
# Label the top_N classes.
yticks = range(0, top_n, 1)
plt.yticks(yticks, [class_names[top_class_indices[x]] for x in yticks])
_ = plt.ylim(-0.5 + np.array([top_n, 0]))
