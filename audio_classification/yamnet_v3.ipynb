# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import csv

import matplotlib.pyplot as plt
from IPython.display import Audio
from IPython.core.display import display
from scipy.io import wavfile
import scipy


# Preprocessing
from sklearn.preprocessing import MinMaxScaler
# from sklearn.cross_validation import KFold
from sklearn.model_selection import train_test_split, KFold

# Performance metrics
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_auc_score

# LSTM
import tensorflow as tf
import tensorflow_hub as hub
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Input, Lambda, Conv2D, BatchNormalization
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense, Activation, MaxPool2D, Flatten, Dropout
from tensorflow.keras.losses import CategoricalCrossentropy

# import tensorflow_io as tfio
# Out:
# /var/folders/gp/1_dqbwsn08sbtf7s0k5q2lsc0000gn/T/ipykernel_71090/4222563939.py:9: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display

# %%
import os
import os
import sys
import shutil
import librosa
import pickle

# %%
CURR_DIR = os.getcwd()

# %% [markdown]
# # Utilities

# %%
DATA_DIR = os.path.join(CURR_DIR, "Crema")

# %% [markdown]
# ### Resample waveform to 16k

# %%
def ensure_sample_rate(original_sample_rate, waveform,
                       desired_sample_rate=16000):
  """Resample waveform if required."""
  if original_sample_rate != desired_sample_rate:
    desired_length = int(round(float(len(waveform)) /
                               original_sample_rate * desired_sample_rate))
    waveform = scipy.signal.resample(waveform, desired_length)
  return desired_sample_rate, waveform

# %% [markdown]
# ### Function to load audio files

# %%
@tf.function
def load_wavfile(filename):
    """ Load a WAV file, convert it to a float tensor, resample to 16 kHz single-channel audio. """
    file_contents = tf.io.read_file(filename)
    wav, sample_rate = tf.audio.decode_wav(
          file_contents,
          desired_channels=1)
    wav = tf.squeeze(wav, axis=-1)
    sample_rate = tf.cast(sample_rate, dtype=tf.int64)
    wav = tfio.audio.resample(wav, rate_in=sample_rate, rate_out=16000)
    return wav

# %% [markdown]
# # Data Exploration

# %% [markdown]
# ### Happy

# %%
# wav_file_name = 'speech_whistling2.wav'
category = "happy"
wav_file_name = '2c9c46babe.wav'

file_path = os.path.join(DATA_DIR, category, wav_file_name)

sample_rate, wav_data = wavfile.read(file_path, 'rb')
sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

# Show some basic information about the audio.
duration = len(wav_data)/sample_rate
print(f'Sample rate: {sample_rate} Hz')
print(f'Total duration: {duration:.2f}s')
print(f'Size of the input: {len(wav_data)}')

# Listening to the wav file.
Audio(wav_data, rate=sample_rate)
plt.plot(wav_data)
# Out:
# Sample rate: 16000 Hz
# Total duration: 3.52s
# Size of the input: 56287
# /var/folders/gp/1_dqbwsn08sbtf7s0k5q2lsc0000gn/T/ipykernel_59475/788395808.py:7: WavFileWarning: Chunk (non-data) not understood, skipping it.
#   sample_rate, wav_data = wavfile.read(file_path, 'rb')

# %% [markdown]
# ### Sad

# %%
# wav_file_name = 'speech_whistling2.wav'
category = "sad"
wav_file_name = '1ac2b3d011.wav'

file_path = os.path.join(DATA_DIR, category, wav_file_name)

sample_rate, wav_data = wavfile.read(file_path, 'rb')
sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

# Show some basic information about the audio.
duration = len(wav_data)/sample_rate
print(f'Sample rate: {sample_rate} Hz')
print(f'Total duration: {duration:.2f}s')
print(f'Size of the input: {len(wav_data)}')

# Listening to the wav file.
Audio(wav_data, rate=sample_rate)
plt.plot(wav_data)
# Out:
# Sample rate: 16000 Hz
# Total duration: 2.17s
# Size of the input: 34790

# %% [markdown]
# ### Neutral

# %%
# wav_file_name = 'speech_whistling2.wav'
category = "neutral"
wav_file_name = '3a49f17ceb.wav'

file_path = os.path.join(DATA_DIR, category, wav_file_name)

sample_rate, wav_data = wavfile.read(file_path, 'rb')
sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

# Show some basic information about the audio.
duration = len(wav_data)/sample_rate
print(f'Sample rate: {sample_rate} Hz')
print(f'Total duration: {duration:.2f}s')
print(f'Size of the input: {len(wav_data)}')

# Listening to the wav file.
Audio(wav_data, rate=sample_rate)
plt.plot(wav_data)
# Out:
# Sample rate: 16000 Hz
# Total duration: 2.11s
# Size of the input: 33717

# %% [markdown]
# ### Fear

# %%
# wav_file_name = 'speech_whistling2.wav'
category = "fear"
wav_file_name = '0ef63f4364.wav'

file_path = os.path.join(DATA_DIR, category, wav_file_name)

sample_rate, wav_data = wavfile.read(file_path, 'rb')
sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

# Show some basic information about the audio.
duration = len(wav_data)/sample_rate
print(f'Sample rate: {sample_rate} Hz')
print(f'Total duration: {duration:.2f}s')
print(f'Size of the input: {len(wav_data)}')

# Listening to the wav file.
Audio(wav_data, rate=sample_rate)
plt.plot(wav_data)
# Out:
# Sample rate: 16000 Hz
# Total duration: 1.74s
# Size of the input: 27816

# %% [markdown]
# # Recording the files

# %%
ext_to_category = {
    "SAD": "sadness",
    "ANG": "angry",
    "DIS": "disgust",
    "FEA": "fear",
    "HAP": "happy",
    "NEU": "neutral"
}

# %%
rows = []
for file in os.listdir(DATA_DIR):
    if file.startswith("."):
        continue

    file_path = os.path.join(DATA_DIR, file)        
    rel_file_path = os.path.relpath(file_path)

    tmp = rel_file_path.split("_")[2]
    category = ext_to_category[tmp]

    row = {
        "file": file,
        "file_path": rel_file_path, 
        "label": category
    }

    rows.append(row)


# categories

# %%
# rows = []

# for category in categories[:]:
#     CATEGORY_DIR = os.path.join(DATA_DIR, category)

#     for file in os.listdir(CATEGORY_DIR):
#         if file.startswith("."):
#             continue

#         file_path = os.path.join(CATEGORY_DIR, file)        
#         rel_file_path = os.path.relpath(file_path)

#         row = {
#             "file": file,
#             "file_path": rel_file_path, 
#             "label": category
#         }
    
#         rows.append(row)

# %%
df = pd.DataFrame(rows)

# %%
df.head()
# Out:
#                   file                  file_path    label
# 0  1022_ITS_ANG_XX.wav  Crema/1022_ITS_ANG_XX.wav    angry
# 1  1037_ITS_ANG_XX.wav  Crema/1037_ITS_ANG_XX.wav    angry
# 2  1060_ITS_NEU_XX.wav  Crema/1060_ITS_NEU_XX.wav  neutral
# 3  1075_ITS_NEU_XX.wav  Crema/1075_ITS_NEU_XX.wav  neutral
# 4  1073_IOM_DIS_XX.wav  Crema/1073_IOM_DIS_XX.wav  disgust

# %%
df.describe()
# Out:
#                        file                  file_path  label
# count                  7442                       7442   7442
# unique                 7442                       7442      6
# top     1022_ITS_ANG_XX.wav  Crema/1022_ITS_ANG_XX.wav  angry
# freq                      1                          1   1271

# %%
df.isna().sum()
# Out:
# file         0
# file_path    0
# label        0
# dtype: int64

# %%
# # Save datafram
# df.to_csv("crema_dataset_meta.csv", index=False)

# %% [markdown]
# # Data Preprocessing

# %%
waveform = wav_data / tf.int16.max

# %%
# label_to_target = {
#     "sad": 0,
#     "fear": 1,
#     "angry": 2,
#     "neutral": 3, 
#     "happy": 4
# }

label_to_target = {
    "sadness": 0,
    "fear": 1,
    "angry": 2,
    "disgust": 3,
    "neutral": 4, 
    "happy": 5
}

# %%
# Read the meta data
df = pd.read_csv("crema_dataset_meta.csv")
print(len(df))
df.head()
# Out:
# 7442
#                   file                  file_path    label
# 0  1022_ITS_ANG_XX.wav  Crema/1022_ITS_ANG_XX.wav    angry
# 1  1037_ITS_ANG_XX.wav  Crema/1037_ITS_ANG_XX.wav    angry
# 2  1060_ITS_NEU_XX.wav  Crema/1060_ITS_NEU_XX.wav  neutral
# 3  1075_ITS_NEU_XX.wav  Crema/1075_ITS_NEU_XX.wav  neutral
# 4  1073_IOM_DIS_XX.wav  Crema/1073_IOM_DIS_XX.wav  disgust

# %%
df['target'] = df['label'].apply(lambda x: label_to_target[x])

# %%
df['target']
# Out:
# 0       2
# 1       2
# 2       4
# 3       4
# 4       3
#        ..
# 7437    2
# 7438    2
# 7439    2
# 7440    2
# 7441    4
# Name: target, Length: 7442, dtype: int64

# %%
df.isna().sum()
# Out:
# file         0
# file_path    0
# label        0
# target       0
# dtype: int64

# %%
X_train, X_test, y_train, y_test = train_test_split(df['file_path'], df['label'], test_size=0.2, random_state=42)

# %%
df_train = pd.concat([X_train, y_train], axis=1)
df_test = pd.concat([X_test, y_test], axis=1)

# %%
# Save train and test
df_train.to_csv("crema_df_train.csv", index=False)
df_test.to_csv("crema_df_test.csv", index=False)

# %% [markdown]
# ### Manual processing

# %%
def load_audio(file_path, label):
    # file_path_str = bytes.decode(file_path.numpy())
    # print(file_path_str)
    sample_rate, wav_data = wavfile.read(file_path, 'rb')
    sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

    # # Normalise wave data
    # wav_data = wav_data / tf.int16.max

    # Convert to tensor
    wav_data_tensor = tf.convert_to_tensor(wav_data, dtype=tf.float32)
    label_tensor = tf.convert_to_tensor(label, dtype=tf.int64)
    return (wav_data_tensor, label_tensor)

# %%
# Load the model.
yamnet_model = hub.load('https://tfhub.dev/google/yamnet/1')
# Out:
# 2023-04-07 02:37:01.559904: W tensorflow/core/kernels/data/cache_dataset_ops.cc:757] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2023-04-07 02:37:01.569217: W tensorflow/core/kernels/data/cache_dataset_ops.cc:757] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.
# 2023-04-07 02:37:01.575073: W tensorflow/core/kernels/data/cache_dataset_ops.cc:757] The calling iterator did not fully read the dataset being cached. In order to avoid unexpected truncation of the dataset, the partially cached contents of the dataset will be discarded. This can happen if you have an input pipeline similar to `dataset.cache().take(k).repeat()`. You should use `dataset.take(k).cache().repeat()` instead.

# %%
def extract_embedding(wav_data, label):
  ''' run YAMNet to extract embedding from the wav data '''
  scores, embeddings, spectrogram = yamnet_model(wav_data)
  num_embeddings = tf.shape(embeddings)[0]
  return (embeddings,
            tf.repeat(label, num_embeddings))

# %%
scores, embeddings, spectrogram = yamnet_model(wav_data)

# %%
train_ls = []

# %%
for file_path, label in list(zip(X_train, y_train)):
    wav_data_tensor, label_tensor = load_audio(file_path, label)
    train_ls.append((wav_data_tensor, label_tensor))

# %%
train_embedding_tensor_ls = []

# %%
for wave, label in train_ls:
    scores, embeddings, spectrogram = yamnet_model(wave)
    for embedding in embeddings:
        train_embedding_tensor_ls.append((embedding, label))

# %%
# train_wave_tensor_ds = tf.concat(train_ls, axis=0)

# %%
# # Save train_embedding_tensor_ls
# with open("crema_train_embeeding_tensor_ls.pkl", "wb") as file:
#     pickle.dump(train_embedding_tensor_ls, file)

# %%
# Load train_embedding_tensor_ls
with open("crema_train_embeeding_tensor_ls.pkl", "rb") as file:
    train_embedding_tensor_ls = pickle.load(file)

# %%
len(train_embedding_tensor_ls)
# Out:
# 28435

# %%
test_ls = []

# %%
for file_path, label in list(zip(X_test, y_test)):
    wav_data_tensor, label_tensor = load_audio(file_path, label)
    test_ls.append((wav_data_tensor, label_tensor))

# %%
test_embedding_tensor_ls = []

# %%
for wave, label in test_ls:
    scores, embeddings, spectrogram = yamnet_model(wave)
    for embedding in embeddings:
        test_embedding_tensor_ls.append((embedding, label))

# %%
# # Save train_embedding_tensor_ls
# with open("crema_test_embeeding_tensor_ls.pkl", "wb") as file:
#     pickle.dump(test_embedding_tensor_ls, file)

# %%
# Load train_embedding_tensor_ls
with open("crema_test_embeeding_tensor_ls.pkl", "rb") as file:
    test_embedding_tensor_ls = pickle.load(file)

# %%
len(test_embedding_tensor_ls)
# Out:
# 7117

# %% [markdown]
# #### Convert to numpy

# %%
tf.concat(test_embedding_tensor_ls, axis=0)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb Cell 61 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb#Y254sZmlsZQ%3D%3D?line=0'>1</a> tf.concat(test_embedding_tensor_ls, axis=0)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1677, in concat(values, axis, name)
#    1673     ops.convert_to_tensor(
#    1674         axis, name="concat_dim",
#    1675         dtype=dtypes.int32).get_shape().assert_has_rank(0)
#    1676     return identity(values[0], name=name)
# -> 1677 return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1197, in concat_v2(values, axis, name)
#    1195   pass
#    1196 try:
# -> 1197   return concat_v2_eager_fallback(
#    1198       values, axis, name=name, ctx=_ctx)
#    1199 except _core._SymbolicException:
#    1200   pass  # Add nodes to the TensorFlow graph.
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1228, in concat_v2_eager_fallback(values, axis, name, ctx)
#    1224   raise TypeError(
#    1225       "Expected list for 'values' argument to "
#    1226       "'concat_v2' Op, not %r." % values)
#    1227 _attr_N = len(values)
# -> 1228 _attr_T, values = _execute.args_to_matching_eager(list(values), ctx, [])
#    1229 _attr_Tidx, (axis,) = _execute.args_to_matching_eager([axis], ctx, [_dtypes.int32, _dtypes.int64, ], _dtypes.int32)
#    1230 _inputs_flat = list(values) + [axis]
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:273, in args_to_matching_eager(l, ctx, allowed_dtypes, default_dtype)
#     270     tensor = None
#     272 if tensor is None:
# --> 273   tensor = ops.convert_to_tensor(
#     274       t, dtype, preferred_dtype=default_dtype, ctx=ctx)
#     276 ret.append(tensor)
#     277 if dtype is None:
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     161   with Trace(trace_name, **trace_kwargs):
#     162     return func(*args, **kwargs)
# --> 163 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1540, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1535       raise TypeError("convert_to_tensor did not convert to "
#    1536                       "the preferred dtype: %s vs %s " %
#    1537                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1539 if ret is None:
# -> 1540   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1542 if ret is NotImplemented:
#    1543   continue
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1525, in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1523 elif dtype != inferred_dtype:
#    1524   v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# -> 1525 return _autopacking_helper(v, dtype, name or "packed")
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1431, in _autopacking_helper(list_or_tuple, dtype, name)
#    1427 if context.executing_eagerly():
#    1428   # NOTE: Fast path when all the items are tensors, this doesn't do any type
#    1429   # checking.
#    1430   if all(isinstance(elem, core.Tensor) for elem in list_or_tuple):
# -> 1431     return gen_array_ops.pack(list_or_tuple, name=name)
#    1432 must_pack = False
#    1433 converted_elems = []
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:6380, in pack(values, axis, name)
#    6378   return _result
#    6379 except _core._NotOkStatusException as e:
# -> 6380   _ops.raise_from_not_ok_status(e, name)
#    6381 except _core._FallbackException:
#    6382   pass
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#    6860 message = e.message + (" name: " + name if name is not None else "")
#    6861 # pylint: disable=protected-access
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# InvalidArgumentError: cannot compute Pack as input #1(zero-based) was expected to be a float tensor but is a int64 tensor [Op:Pack] name: packed

# %%
temp = []

# %%
train_tensor = []
train_labels = []
for tensor, label in train_embedding_tensor_ls:
    # np_array = tensor.numpy()
    train_tensor.append(tensor)
    train_labels.append(label)

# %%
train_dataset = tf.data.Dataset.from_tensors((train_tensor, train_labels))

# %%
test_tensor = []
test_labels = []
for tensor, label in test_embedding_tensor_ls:
    # np_array = tensor.numpy()
    test_tensor.append(tensor)
    test_labels.append(label)

# %%
test_dataset = tf.data.Dataset.from_tensors((test_tensor, test_labels))

# %%
counter = 0 
for embedding, label in train_dataset:
    if counter > 5:
        break
    
    print(embedding.shape, label)

    counter += 1
# Out:
# (28435, 1024) tf.Tensor([0 0 0 ... 1 1 1], shape=(28435,), dtype=int64)

# %%
train_dataset
# Out:
# <TensorDataset shapes: ((28435, 1024), (28435,)), types: (tf.float32, tf.int64)>

# %% [markdown]
# # Training Model v2

# %%
# class Model(tf.Module):
#     def __init__(self, name=None):
#         super().__init__(name=name)
#         self.dense1 = tf.keras.layers

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1024,), dtype=tf.float32,
                          name='input_embedding'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(6)
], name='my_model')

model.summary()
# Out:
# Model: "my_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_15 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_16 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_17 (Dense)             (None, 6)                 774
# =================================================================
# Total params: 591,238
# Trainable params: 591,238
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
                 optimizer="adam",
                 metrics=['accuracy'])

early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                            patience=5,
                                            restore_best_weights=True)

save_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'model_2/model.epoch{epoch:02d}.hdf5',
    monitor ='val_loss',
    verbose = 1,
    save_best_only = True,
)

callbacks = [early_stop, save_model_checkpoint]

# %%
history = model.fit(train_dataset,
                       epochs=20,
                       validation_data=test_dataset,
                       callbacks=callbacks)
# Out:
# Epoch 1/20
# 1/1 [==============================] - 2s 2s/step - loss: 4.8259 - accuracy: 0.1710 - val_loss: 5.7505 - val_accuracy: 0.2119
#
# Epoch 00001: val_loss improved from inf to 5.75052, saving model to model_2/model.epoch01.hdf5
# Epoch 2/20
# 1/1 [==============================] - 1s 652ms/step - loss: 5.5662 - accuracy: 0.2103 - val_loss: 7.3938 - val_accuracy: 0.2620
#
# Epoch 00002: val_loss did not improve from 5.75052
# Epoch 3/20
# 1/1 [==============================] - 1s 646ms/step - loss: 6.9839 - accuracy: 0.2589 - val_loss: 7.0580 - val_accuracy: 0.2640
#
# Epoch 00003: val_loss did not improve from 5.75052
# Epoch 4/20
# 1/1 [==============================] - 1s 651ms/step - loss: 6.6330 - accuracy: 0.2676 - val_loss: 7.3457 - val_accuracy: 0.1987
#
# Epoch 00004: val_loss did not improve from 5.75052
# Epoch 5/20
# 1/1 [==============================] - 1s 649ms/step - loss: 6.9265 - accuracy: 0.2017 - val_loss: 7.3177 - val_accuracy: 0.2021
#
# Epoch 00005: val_loss did not improve from 5.75052
# Epoch 6/20
# 1/1 [==============================] - 1s 681ms/step - loss: 6.9252 - accuracy: 0.2041 - val_loss: 6.1632 - val_accuracy: 0.2237
#
# Epoch 00006: val_loss did not improve from 5.75052

# %% [markdown]
# # Training MOdel v1

# %%
# train_wave_tensor_ds = tf.concat(train_ls, axis=0)
# Out:
# ---------------------------------------------------------------------------
#
# InvalidArgumentError                      Traceback (most recent call last)
#
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb Cell 42 in <cell line: 1>()
#
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb#Y144sZmlsZQ%3D%3D?line=0'>1</a> train_wave_tensor_ds = tf.concat(train_ls, axis=0)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#
#     200 try:
#
# --> 201   return target(*args, **kwargs)
#
#     202 except (TypeError, ValueError):
#
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#
#     205   result = dispatch(wrapper, args, kwargs)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1677, in concat(values, axis, name)
#
#    1673     ops.convert_to_tensor(
#
#    1674         axis, name="concat_dim",
#
#    1675         dtype=dtypes.int32).get_shape().assert_has_rank(0)
#
#    1676     return identity(values[0], name=name)
#
# -> 1677 return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1197, in concat_v2(values, axis, name)
#
#    1195   pass
#
#    1196 try:
#
# -> 1197   return concat_v2_eager_fallback(
#
#    1198       values, axis, name=name, ctx=_ctx)
#
#    1199 except _core._SymbolicException:
#
#    1200   pass  # Add nodes to the TensorFlow graph.
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1228, in concat_v2_eager_fallback(values, axis, name, ctx)
#
#    1224   raise TypeError(
#
#    1225       "Expected list for 'values' argument to "
#
#    1226       "'concat_v2' Op, not %r." % values)
#
#    1227 _attr_N = len(values)
#
# -> 1228 _attr_T, values = _execute.args_to_matching_eager(list(values), ctx, [])
#
#    1229 _attr_Tidx, (axis,) = _execute.args_to_matching_eager([axis], ctx, [_dtypes.int32, _dtypes.int64, ], _dtypes.int32)
#
#    1230 _inputs_flat = list(values) + [axis]
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/eager/execute.py:273, in args_to_matching_eager(l, ctx, allowed_dtypes, default_dtype)
#
#     270     tensor = None
#
#     272 if tensor is None:
#
# --> 273   tensor = ops.convert_to_tensor(
#
#     274       t, dtype, preferred_dtype=default_dtype, ctx=ctx)
#
#     276 ret.append(tensor)
#
#     277 if dtype is None:
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#
#     161   with Trace(trace_name, **trace_kwargs):
#
#     162     return func(*args, **kwargs)
#
# --> 163 return func(*args, **kwargs)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1540, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#
#    1535       raise TypeError("convert_to_tensor did not convert to "
#
#    1536                       "the preferred dtype: %s vs %s " %
#
#    1537                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#
#    1539 if ret is None:
#
# -> 1540   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#
#    1542 if ret is NotImplemented:
#
#    1543   continue
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1525, in _autopacking_conversion_function(v, dtype, name, as_ref)
#
#    1523 elif dtype != inferred_dtype:
#
#    1524   v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
#
# -> 1525 return _autopacking_helper(v, dtype, name or "packed")
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1431, in _autopacking_helper(list_or_tuple, dtype, name)
#
#    1427 if context.executing_eagerly():
#
#    1428   # NOTE: Fast path when all the items are tensors, this doesn't do any type
#
#    1429   # checking.
#
#    1430   if all(isinstance(elem, core.Tensor) for elem in list_or_tuple):
#
# -> 1431     return gen_array_ops.pack(list_or_tuple, name=name)
#
#    1432 must_pack = False
#
#    1433 converted_elems = []
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:6380, in pack(values, axis, name)
#
#    6378   return _result
#
#    6379 except _core._NotOkStatusException as e:
#
# -> 6380   _ops.raise_from_not_ok_status(e, name)
#
#    6381 except _core._FallbackException:
#
#    6382   pass
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#
#    6860 message = e.message + (" name: " + name if name is not None else "")
#
#    6861 # pylint: disable=protected-access
#
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
#
#
# File <string>:3, in raise_from(value, from_value)
#
#
#
# InvalidArgumentError: cannot compute Pack as input #1(zero-based) was expected to be a float tensor but is a int64 tensor [Op:Pack] name: packed

# %%
# Save train_embedding_tensor_ls
with open("train_embeeding_tensor_ls.pkl", "wb") as file:
    pickle.dump(train_embedding_tensor_ls, file)

# %%
tf.convert_to_tensor(train_ls)
# Out:
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb Cell 44 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb#Y161sZmlsZQ%3D%3D?line=0'>1</a> tf.convert_to_tensor(train_ls)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#     200 try:
# --> 201   return target(*args, **kwargs)
#     202 except (TypeError, ValueError):
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#     205   result = dispatch(wrapper, args, kwargs)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1404, in convert_to_tensor_v2_with_dispatch(value, dtype, dtype_hint, name)
#    1340 @tf_export("convert_to_tensor", v1=[])
#    1341 @dispatch.add_dispatch_support
#    1342 def convert_to_tensor_v2_with_dispatch(
#    1343     value, dtype=None, dtype_hint=None, name=None):
#    1344   """Converts the given `value` to a `Tensor`.
#    1345
#    1346   This function converts Python objects of various types to `Tensor`
#    (...)
#    1402     ValueError: If the `value` is a tensor not of given `dtype` in graph mode.
#    1403   """
# -> 1404   return convert_to_tensor_v2(
#    1405       value, dtype=dtype, dtype_hint=dtype_hint, name=name)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1410, in convert_to_tensor_v2(value, dtype, dtype_hint, name)
#    1408 def convert_to_tensor_v2(value, dtype=None, dtype_hint=None, name=None):
#    1409   """Converts the given `value` to a `Tensor`."""
# -> 1410   return convert_to_tensor(
#    1411       value=value,
#    1412       dtype=dtype,
#    1413       name=name,
#    1414       preferred_dtype=dtype_hint,
#    1415       as_ref=False)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/profiler/trace.py:163, in trace_wrapper.<locals>.inner_wrapper.<locals>.wrapped(*args, **kwargs)
#     161   with Trace(trace_name, **trace_kwargs):
#     162     return func(*args, **kwargs)
# --> 163 return func(*args, **kwargs)
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:1540, in convert_to_tensor(value, dtype, name, as_ref, preferred_dtype, dtype_hint, ctx, accepted_result_types)
#    1535       raise TypeError("convert_to_tensor did not convert to "
#    1536                       "the preferred dtype: %s vs %s " %
#    1537                       (ret.dtype.base_dtype, preferred_dtype.base_dtype))
#    1539 if ret is None:
# -> 1540   ret = conversion_func(value, dtype=dtype, name=name, as_ref=as_ref)
#    1542 if ret is NotImplemented:
#    1543   continue
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1525, in _autopacking_conversion_function(v, dtype, name, as_ref)
#    1523 elif dtype != inferred_dtype:
#    1524   v = nest.map_structure(_cast_nested_seqs_to_dtype(dtype), v)
# -> 1525 return _autopacking_helper(v, dtype, name or "packed")
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1444, in _autopacking_helper(list_or_tuple, dtype, name)
#    1442   must_pack = True
#    1443 elif isinstance(elem, (list, tuple)):
# -> 1444   converted_elem = _autopacking_helper(elem, dtype, str(i))
#    1445   if isinstance(converted_elem, core.Tensor):
#    1446     must_pack = True
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1431, in _autopacking_helper(list_or_tuple, dtype, name)
#    1427 if context.executing_eagerly():
#    1428   # NOTE: Fast path when all the items are tensors, this doesn't do any type
#    1429   # checking.
#    1430   if all(isinstance(elem, core.Tensor) for elem in list_or_tuple):
# -> 1431     return gen_array_ops.pack(list_or_tuple, name=name)
#    1432 must_pack = False
#    1433 converted_elems = []
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:6380, in pack(values, axis, name)
#    6378   return _result
#    6379 except _core._NotOkStatusException as e:
# -> 6380   _ops.raise_from_not_ok_status(e, name)
#    6381 except _core._FallbackException:
#    6382   pass
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#    6860 message = e.message + (" name: " + name if name is not None else "")
#    6861 # pylint: disable=protected-access
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
# File <string>:3, in raise_from(value, from_value)
#
# InvalidArgumentError: cannot compute Pack as input #1(zero-based) was expected to be a float tensor but is a int64 tensor [Op:Pack] name: 0

# %%
test_ls = []

# %%
for file_path, label in list(zip(X_train, y_train)):
    wav_data_tensor, label_tensor = load_audio(file_path, label)
    train_ls.append((wav_data_tensor, label_tensor))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb Cell 86 in <cell line: 1>()
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=0'>1</a> for file_path, label in list(zip(X_train, y_train)):
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=1'>2</a>     wav_data_tensor, label_tensor = load_audio(file_path, label)
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=2'>3</a>     train_ls.append((wav_data_tensor, label_tensor))
#
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb Cell 86 in load_audio(file_path, label)
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=2'>3</a> def load_audio(file_path, label):
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=3'>4</a>     file_path_str = bytes.decode(file_path.numpy())
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=4'>5</a>     print(file_path_str, label)
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v3.ipynb#Y145sZmlsZQ%3D%3D?line=5'>6</a>     sample_rate, wav_data = wavfile.read(file_path_str, 'rb')
#
# AttributeError: 'str' object has no attribute 'numpy'

# %%
train_wave_tensor_ds = tf.concat(train_ls, axis=0)
# Out:
# ---------------------------------------------------------------------------
#
# InvalidArgumentError                      Traceback (most recent call last)
#
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb Cell 42 in <cell line: 1>()
#
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v2.ipynb#Y144sZmlsZQ%3D%3D?line=0'>1</a> train_wave_tensor_ds = tf.concat(train_ls, axis=0)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:201, in add_dispatch_support.<locals>.wrapper(*args, **kwargs)
#
#     199 """Call target, and fall back on dispatchers if there is a TypeError."""
#
#     200 try:
#
# --> 201   return target(*args, **kwargs)
#
#     202 except (TypeError, ValueError):
#
#     203   # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
#     204   # TypeError, when given unexpected types.  So we need to catch both.
#
#     205   result = dispatch(wrapper, args, kwargs)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/array_ops.py:1677, in concat(values, axis, name)
#
#    1673     ops.convert_to_tensor(
#
#    1674         axis, name="concat_dim",
#
#    1675         dtype=dtypes.int32).get_shape().assert_has_rank(0)
#
#    1676     return identity(values[0], name=name)
#
# -> 1677 return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/ops/gen_array_ops.py:1193, in concat_v2(values, axis, name)
#
#    1191   return _result
#
#    1192 except _core._NotOkStatusException as e:
#
# -> 1193   _ops.raise_from_not_ok_status(e, name)
#
#    1194 except _core._FallbackException:
#
#    1195   pass
#
#
#
# File ~/opt/anaconda3/envs/carrosell2/lib/python3.8/site-packages/tensorflow/python/framework/ops.py:6862, in raise_from_not_ok_status(e, name)
#
#    6860 message = e.message + (" name: " + name if name is not None else "")
#
#    6861 # pylint: disable=protected-access
#
# -> 6862 six.raise_from(core._status_to_exception(e.code, message), None)
#
#
#
# File <string>:3, in raise_from(value, from_value)
#
#
#
# InvalidArgumentError: OpKernel 'ConcatV2' has constraint on attr 'T' not in NodeDef '[N=0, Tidx=DT_INT32]', KernelDef: 'op: "ConcatV2" device_type: "CPU" constraint { name: "T" allowed_values { list { type: DT_UINT64 } } } host_memory_arg: "axis"' [Op:ConcatV2] name: concat

# %%
# Save wave 
with open("train_wave_tensor", "wb") as file:
    pickle.dump(train_ls, file)

# %%
train_ls[2][1].numpy()
# Out:
# 2

# %%
# # Save the train and test set
# df_train = pd.concat([X_train, y_train], axis=1)
# print(df_train.head())

# df_train.to_csv("df_train.csv", index=False)

# df_test = pd.concat([X_test, y_test], axis=1)
# print(df_test.head())

# df_test.to_csv("df_test.csv", index=False)

# %%
wav1 = tf.convert_to_tensor(wav_data)
wav2 = tf.convert_to_tensor(wav_data)

# %%
ls = [wav1, wav2]

# %%
waves = tf.stack(ls)

# %%
waves.shape
# Out:
# TensorShape([2, 27520])

# %%
X_train
# Out:
# 2087      huge_collated_dataset/sad/sad_2_5_174_vesus.wav
# 5848    huge_collated_dataset/neutral/neutral_5_5_108_...
# 8532    huge_collated_dataset/angry/angry_7_6_78_vesus...
# 96      huge_collated_dataset/happy/happy_4_4_206_vesu...
# 5751    huge_collated_dataset/neutral/neutral_9_6_33_v...
#                               ...
# 5734    huge_collated_dataset/neutral/neutral_1_3_229_...
# 5191    huge_collated_dataset/neutral/neutral_5_5_85_v...
# 5390    huge_collated_dataset/neutral/neutral_8_1_145_...
# 860     huge_collated_dataset/happy/happy_2_2_143_vesu...
# 7270    huge_collated_dataset/angry/angry_4_1_92_vesus...
# Name: file_path, Length: 6861, dtype: object

# %% [markdown]
# # With Tensor Slices Pipeline

# %%
# label_to_target = {
#     "sad": 0,
#     "fear": 1,
#     "angry": 2,
#     "neutral": 3, 
#     "happy": 4
# }

label_to_target = {
    "sadness": 0,
    "fear": 1,
    "angry": 2,
    "disgust": 3,
    "neutral": 4, 
    "happy": 5
}

# %%
df_train = pd.read_csv("crema_df_train.csv")
df_test = pd.read_csv("crema_df_test.csv")

# %%
X_train = df_train['file_path'][:]
y_train = df_train['label'][:].apply(lambda x: label_to_target[x])
X_test = df_test['file_path']
y_test = df_test['label'].apply(lambda x: label_to_target[x])

# %%
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train))
train_ds.element_spec
# Out:
# (TensorSpec(shape=(), dtype=tf.string, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test))
test_ds.element_spec
# Out:
# (TensorSpec(shape=(), dtype=tf.string, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
# Helper load audio function
# @tf.function
def load_audio(file_path, label):
    file_path_str = bytes.decode(file_path.numpy())
    print(file_path_str, label)
    sample_rate, wav_data = wavfile.read(file_path_str, 'rb')
    sample_rate, wav_data = ensure_sample_rate(sample_rate, wav_data)

    # Normalise wave data
    wav_data = wav_data / tf.int16.max

    # Convert to tensor
    wav_data_tensor = tf.convert_to_tensor(wav_data, dtype=tf.float32)
    return (wav_data_tensor, label)

# %%
# train_audio_ds = train_ds.map(load_audio)

# %%
train_audio_ds = train_ds.map(lambda x, y: tf.py_function(load_audio, [x, y], [tf.float32, tf.int64]))
train_audio_ds
# Out:
# <MapDataset shapes: (<unknown>, <unknown>), types: (tf.float32, tf.int64)>

# %%
train_audio_ds.element_spec
# Out:
# (TensorSpec(shape=<unknown>, dtype=tf.float32, name=None),
#  TensorSpec(shape=<unknown>, dtype=tf.int64, name=None))

# %%
test_audio_ds = test_ds.map(lambda x, y: tf.py_function(load_audio, [x, y], [tf.float32, tf.int64]))
test_audio_ds
# Out:
# <MapDataset shapes: (<unknown>, <unknown>), types: (tf.float32, tf.int64)>

# %%
test_audio_ds.element_spec
# Out:
# (TensorSpec(shape=<unknown>, dtype=tf.float32, name=None),
#  TensorSpec(shape=<unknown>, dtype=tf.int64, name=None))

# %%
# for wave, target in train_audio_ds:
#     print(wave[:5])

# %% [markdown]
# # Transfer learning with YAMNet

# %%
# Load the model.
yamnet_model = hub.load('https://tfhub.dev/google/yamnet/1')

# %%
def extract_embedding(wav_data, label):
  ''' run YAMNet to extract embedding from the wav data '''
  scores, embeddings, spectrogram = yamnet_model(wav_data)
  num_embeddings = tf.shape(embeddings)[0]
  return (embeddings,
            tf.repeat(label, num_embeddings))

# %%
main_ds = train_audio_ds.map(extract_embedding).unbatch()
main_ds.element_spec
# Out:
# (TensorSpec(shape=(1024,), dtype=tf.float32, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
val_ds = test_audio_ds.map(extract_embedding).unbatch()
val_ds.element_spec
# Out:
# (TensorSpec(shape=(1024,), dtype=tf.float32, name=None),
#  TensorSpec(shape=(), dtype=tf.int64, name=None))

# %%
# # Save the main_ds
# tf.data.experimental.save(main_ds, "./main_ds")

# # Save the val_ds
# tf.data.experimental.save(val_ds, "./val_ds")

# %%
main_train_ds = main_ds.cache().batch(32).prefetch(tf.data.AUTOTUNE)
val_train_ds = val_ds.cache().batch(32).prefetch(tf.data.AUTOTUNE)
# test_ds = test_ds.cache().batch(32).prefetch(tf.data.AUTOTUNE)

# %% [markdown]
# # Training the Model

# %%
# class Model(tf.Module):
#     def __init__(self, name=None):
#         super().__init__(name=name)
#         self.dense1 = tf.keras.layers

model = tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1024), dtype=tf.float32,
                          name='input_embedding'),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(6)
], name='my_model')

model.summary()
# Out:
# Model: "my_model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dense_19 (Dense)             (None, 128)               65664
# _________________________________________________________________
# dense_20 (Dense)             (None, 6)                 774
# =================================================================
# Total params: 591,238
# Trainable params: 591,238
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
                 optimizer="adam",
                 metrics=['accuracy'])

early_stop = tf.keras.callbacks.EarlyStopping(monitor='loss',
                                            patience=3,
                                            restore_best_weights=True)

save_model_checkpoint = tf.keras.callbacks.ModelCheckpoint(
    'model_1/model.epoch{epoch:02d}-loss{val_loss:.2f}.hdf5',
    monitor ='val_loss',
    verbose = 1,
    save_best_only = True,
)

callbacks = [early_stop, save_model_checkpoint]

# %%
history = model.fit(main_train_ds,
                       epochs=20,
                       validation_data=val_train_ds,
                       callbacks=callbacks)
# Out:
# Epoch 1/20
# Crema/1003_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1047_IWW_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1027_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1053_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1062_ITS_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1017_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1043_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1053_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_train_function.<locals>.train_function at 0x7fb052c573a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:5 out of the last 10 calls to <function Model.make_train_function.<locals>.train_function at 0x7fb052c573a0> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
#       1/Unknown - 1s 539ms/step - loss: 7.2257 - accuracy: 0.3125Crema/1039_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1052_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1025_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1084_IOM_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1027_IEO_ANG_LO.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1015_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1017_IOM_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#       2/Unknown - 1s 388ms/step - loss: 6.3677 - accuracy: 0.2734Crema/1079_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1087_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1047_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1019_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1061_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1046_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1041_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1039_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#       3/Unknown - 1s 369ms/step - loss: 5.6686 - accuracy: 0.2448Crema/1046_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1055_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1078_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1063_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1068_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1028_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1016_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#       4/Unknown - 2s 347ms/step - loss: 5.1642 - accuracy: 0.2344Crema/1072_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1001_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1090_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1064_IOM_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1004_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1056_DFA_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1038_IEO_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#       5/Unknown - 2s 330ms/step - loss: 4.7871 - accuracy: 0.2200Crema/1080_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1030_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1007_ITH_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1008_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1066_IEO_FEA_LO.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1056_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1078_MTI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#       6/Unknown - 2s 324ms/step - loss: 4.4945 - accuracy: 0.2068Crema/1089_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1019_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1080_TIE_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1006_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1058_TIE_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1072_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#       7/Unknown - 3s 333ms/step - loss: 4.2601 - accuracy: 0.2008Crema/1001_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1058_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1006_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1028_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1054_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1018_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1090_TAI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#       8/Unknown - 3s 323ms/step - loss: 4.0678 - accuracy: 0.1987Crema/1022_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1049_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1033_IOM_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1005_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1053_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1027_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1074_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#       9/Unknown - 3s 322ms/step - loss: 3.9067 - accuracy: 0.1947Crema/1036_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1005_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1058_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1085_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1033_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1030_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1050_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#      10/Unknown - 3s 320ms/step - loss: 3.7695 - accuracy: 0.1899Crema/1075_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1064_IEO_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1039_DFA_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1013_ITH_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1045_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1041_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1030_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      11/Unknown - 4s 319ms/step - loss: 3.6512 - accuracy: 0.1882Crema/1087_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1069_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1020_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1039_ITH_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1021_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1018_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
#      12/Unknown - 4s 321ms/step - loss: 3.5479 - accuracy: 0.1879Crema/1013_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1046_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1074_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1033_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1082_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1047_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1016_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      13/Unknown - 4s 318ms/step - loss: 3.4568 - accuracy: 0.1884Crema/1012_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1050_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1021_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1086_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1030_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1027_IEO_FEA_LO.wav tf.Tensor(1, shape=(), dtype=int64)
#      14/Unknown - 5s 316ms/step - loss: 3.3758 - accuracy: 0.1900Crema/1059_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1044_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1002_IEO_ANG_HI.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1038_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1053_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1089_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1012_DFA_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      15/Unknown - 5s 313ms/step - loss: 3.3033 - accuracy: 0.1915Crema/1081_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1030_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1019_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1037_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1015_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1065_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1036_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
#      16/Unknown - 5s 317ms/step - loss: 3.2378 - accuracy: 0.1924Crema/1031_DFA_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1074_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1049_TIE_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1027_IOM_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1019_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1049_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1010_DFA_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1081_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
#      17/Unknown - 6s 319ms/step - loss: 3.1785 - accuracy: 0.1940Crema/1017_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1050_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1072_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1001_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1009_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1042_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1032_TIE_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      18/Unknown - 6s 316ms/step - loss: 3.1244 - accuracy: 0.1951Crema/1059_DFA_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1008_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1064_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1090_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1089_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1039_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      19/Unknown - 6s 315ms/step - loss: 3.0749 - accuracy: 0.1955Crema/1009_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1084_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1083_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1017_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1057_DFA_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1029_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      20/Unknown - 6s 311ms/step - loss: 3.0293 - accuracy: 0.1958Crema/1006_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1076_TIE_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1010_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1067_IEO_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1050_DFA_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1090_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1090_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1016_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
#      21/Unknown - 7s 311ms/step - loss: 2.9872 - accuracy: 0.1958Crema/1071_IEO_ANG_LO.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1059_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1077_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1061_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1085_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1046_IOM_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1041_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
#      22/Unknown - 7s 310ms/step - loss: 2.9483 - accuracy: 0.1959Crema/1053_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1051_ITH_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1001_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1030_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1039_TSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      23/Unknown - 7s 307ms/step - loss: 2.9120 - accuracy: 0.1958Crema/1086_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1007_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1042_DFA_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1062_IEO_HAP_LO.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1087_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1009_IOM_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1033_ITH_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
#      24/Unknown - 8s 309ms/step - loss: 2.8783 - accuracy: 0.1956Crema/1024_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1085_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1028_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1071_DFA_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1022_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1005_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      25/Unknown - 8s 306ms/step - loss: 2.8467 - accuracy: 0.1953Crema/1021_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1072_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1049_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1066_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1087_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1023_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1003_TAI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      26/Unknown - 8s 306ms/step - loss: 2.8171 - accuracy: 0.1949Crema/1014_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1046_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1047_IOM_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1018_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1033_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1083_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1009_TIE_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      27/Unknown - 8s 304ms/step - loss: 2.7893 - accuracy: 0.1945Crema/1077_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1089_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1038_ITS_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1017_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1091_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1032_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      28/Unknown - 9s 303ms/step - loss: 2.7632 - accuracy: 0.1940Crema/1045_IOM_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1015_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1066_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1066_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1001_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1075_IWW_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1019_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#      29/Unknown - 9s 305ms/step - loss: 2.7385 - accuracy: 0.1936Crema/1050_TAI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1066_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1032_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1004_IEO_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1068_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1035_ITS_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1041_TSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      30/Unknown - 9s 307ms/step - loss: 2.7153 - accuracy: 0.1933Crema/1012_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1001_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1084_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1074_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1065_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#      31/Unknown - 10s 306ms/step - loss: 2.6932 - accuracy: 0.1930Crema/1063_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1080_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1026_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1025_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1010_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1008_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1004_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1083_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      32/Unknown - 10s 307ms/step - loss: 2.6723 - accuracy: 0.1929Crema/1089_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1058_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1091_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1029_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1042_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1017_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
#      33/Unknown - 10s 304ms/step - loss: 2.6524 - accuracy: 0.1928Crema/1041_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1080_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1010_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1086_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1017_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1042_IEO_FEA_LO.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1001_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#      34/Unknown - 11s 304ms/step - loss: 2.6336 - accuracy: 0.1927Crema/1079_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1061_TIE_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1058_DFA_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1039_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1063_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1014_ITS_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      35/Unknown - 11s 304ms/step - loss: 2.6156 - accuracy: 0.1929Crema/1016_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1012_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1045_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1069_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1066_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1036_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1015_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
#      36/Unknown - 11s 305ms/step - loss: 2.5984 - accuracy: 0.1929Crema/1025_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1049_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1046_ITS_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1083_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1003_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1054_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
#      37/Unknown - 11s 304ms/step - loss: 2.5821 - accuracy: 0.1929Crema/1051_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1084_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1012_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1034_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1087_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1025_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1043_DFA_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1068_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      38/Unknown - 12s 304ms/step - loss: 2.5664 - accuracy: 0.1930Crema/1004_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1026_IEO_HAP_LO.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1011_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1026_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1056_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1040_TIE_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1030_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      39/Unknown - 12s 305ms/step - loss: 2.5514 - accuracy: 0.1930Crema/1009_IWW_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1059_IOM_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1045_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1067_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1038_DFA_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      40/Unknown - 12s 303ms/step - loss: 2.5371 - accuracy: 0.1930Crema/1060_IWW_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1007_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1075_TIE_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1081_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1026_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1041_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      41/Unknown - 13s 302ms/step - loss: 2.5233 - accuracy: 0.1930Crema/1071_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1015_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1082_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1083_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1087_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1006_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1012_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      42/Unknown - 13s 302ms/step - loss: 2.5101 - accuracy: 0.1930Crema/1009_IEO_SAD_LO.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1037_IEO_ANG_HI.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1033_TIE_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1022_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1044_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1090_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1032_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
#      43/Unknown - 13s 302ms/step - loss: 2.4974 - accuracy: 0.1930Crema/1045_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1012_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1071_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1043_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1081_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1049_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1081_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      44/Unknown - 14s 302ms/step - loss: 2.4853 - accuracy: 0.1932Crema/1010_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1055_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1008_MTI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1087_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1011_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1065_IOM_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      45/Unknown - 14s 302ms/step - loss: 2.4735 - accuracy: 0.1932Crema/1076_TIE_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1085_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1010_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1002_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1082_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1037_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
#      46/Unknown - 14s 300ms/step - loss: 2.4622 - accuracy: 0.1932Crema/1077_TIE_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1079_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1085_IWW_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1007_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1087_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1057_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1070_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      47/Unknown - 14s 300ms/step - loss: 2.4513 - accuracy: 0.1932Crema/1077_TAI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1065_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1062_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1008_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1014_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1075_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1082_TAI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      48/Unknown - 15s 300ms/step - loss: 2.4408 - accuracy: 0.1931Crema/1014_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1080_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1045_MTI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1063_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1056_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1060_ITS_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1026_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1069_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      49/Unknown - 15s 300ms/step - loss: 2.4306 - accuracy: 0.1931Crema/1030_IEO_FEA_LO.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1024_ITH_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1056_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1018_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1002_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1011_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1089_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
#      50/Unknown - 15s 300ms/step - loss: 2.4208 - accuracy: 0.1930Crema/1015_IEO_ANG_HI.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1023_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1073_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1058_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1075_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1087_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1016_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      51/Unknown - 16s 300ms/step - loss: 2.4114 - accuracy: 0.1929Crema/1018_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1032_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1090_TIE_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1065_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1036_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1061_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      52/Unknown - 16s 299ms/step - loss: 2.4022 - accuracy: 0.1929Crema/1009_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1029_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1027_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1085_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1035_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1021_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1075_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
#      53/Unknown - 16s 299ms/step - loss: 2.3933 - accuracy: 0.1929Crema/1046_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1045_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1080_TIE_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1062_IWW_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1035_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1004_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      54/Unknown - 16s 298ms/step - loss: 2.3847 - accuracy: 0.1928Crema/1041_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1057_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1042_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1073_TIE_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1042_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1088_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      55/Unknown - 17s 297ms/step - loss: 2.3764 - accuracy: 0.1928Crema/1038_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1050_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1034_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1082_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1005_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1041_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1080_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#      56/Unknown - 17s 297ms/step - loss: 2.3683 - accuracy: 0.1928Crema/1041_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1065_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1060_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1081_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1071_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1020_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
#      57/Unknown - 17s 297ms/step - loss: 2.3605 - accuracy: 0.1928Crema/1002_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1026_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1016_MTI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1091_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1057_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1081_ITS_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1081_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      58/Unknown - 17s 297ms/step - loss: 2.3529 - accuracy: 0.1927Crema/1035_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1006_IEO_ANG_HI.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1029_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1025_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1056_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1066_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1046_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1019_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      59/Unknown - 18s 297ms/step - loss: 2.3456 - accuracy: 0.1926Crema/1004_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1005_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1010_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1025_ITH_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1002_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1032_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#      60/Unknown - 18s 296ms/step - loss: 2.3384 - accuracy: 0.1926Crema/1048_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1080_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1029_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1068_IEO_FEA_LO.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1049_IOM_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1068_TAI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      61/Unknown - 18s 296ms/step - loss: 2.3314 - accuracy: 0.1925Crema/1071_IOM_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1028_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1045_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1052_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1066_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1083_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      62/Unknown - 19s 296ms/step - loss: 2.3247 - accuracy: 0.1924Crema/1048_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1045_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1073_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1081_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1003_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1050_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      63/Unknown - 19s 296ms/step - loss: 2.3181 - accuracy: 0.1923Crema/1029_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1081_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1074_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1063_IWW_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1022_TIE_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1037_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1005_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#      64/Unknown - 19s 296ms/step - loss: 2.3117 - accuracy: 0.1922Crema/1017_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1079_DFA_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1004_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1027_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1061_DFA_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1045_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
#      65/Unknown - 20s 297ms/step - loss: 2.3054 - accuracy: 0.1923Crema/1059_TIE_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1073_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1069_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1018_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1048_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1088_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1052_TSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      66/Unknown - 20s 297ms/step - loss: 2.2993 - accuracy: 0.1923Crema/1090_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1079_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1015_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1046_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1020_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1041_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
#      67/Unknown - 20s 296ms/step - loss: 2.2934 - accuracy: 0.1923Crema/1017_ITH_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1032_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1007_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1039_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1032_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1070_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      68/Unknown - 20s 295ms/step - loss: 2.2877 - accuracy: 0.1924Crema/1018_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1028_IOM_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1019_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1071_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1044_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1005_ITH_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1072_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      69/Unknown - 21s 296ms/step - loss: 2.2820 - accuracy: 0.1924Crema/1076_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1070_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1031_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1054_DFA_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1027_IWW_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1010_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1091_TIE_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      70/Unknown - 21s 295ms/step - loss: 2.2765 - accuracy: 0.1924Crema/1085_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1020_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1038_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1001_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1014_IWW_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1016_IWW_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1040_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      71/Unknown - 21s 296ms/step - loss: 2.2712 - accuracy: 0.1924Crema/1015_ITH_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1038_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1002_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1002_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1047_IEO_ANG_HI.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1008_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      72/Unknown - 22s 295ms/step - loss: 2.2660 - accuracy: 0.1925Crema/1009_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1067_IOM_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1027_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1061_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1082_IEO_SAD_LO.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1003_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1066_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
#      73/Unknown - 22s 296ms/step - loss: 2.2609 - accuracy: 0.1925Crema/1088_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1019_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1040_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1075_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1060_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1058_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
#      74/Unknown - 22s 295ms/step - loss: 2.2559 - accuracy: 0.1926Crema/1003_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1056_ITH_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1016_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1068_TIE_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1020_IEO_ANG_HI.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1021_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      75/Unknown - 22s 294ms/step - loss: 2.2510 - accuracy: 0.1926Crema/1054_TIE_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1079_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1085_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1090_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1080_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1073_IOM_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1065_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      76/Unknown - 23s 295ms/step - loss: 2.2463 - accuracy: 0.1926Crema/1055_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1035_ITH_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1043_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1051_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1064_IEO_HAP_LO.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1056_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
#      77/Unknown - 23s 294ms/step - loss: 2.2416 - accuracy: 0.1926Crema/1004_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1020_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1075_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1047_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1045_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1079_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
#      78/Unknown - 23s 294ms/step - loss: 2.2371 - accuracy: 0.1926Crema/1082_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1062_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1010_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1053_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1048_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1072_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1014_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1088_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      79/Unknown - 24s 295ms/step - loss: 2.2326 - accuracy: 0.1926Crema/1011_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1083_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1015_IEO_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1043_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1057_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1083_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      80/Unknown - 24s 294ms/step - loss: 2.2283 - accuracy: 0.1926Crema/1040_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1089_IEO_ANG_HI.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1031_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1031_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1086_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1006_TSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      81/Unknown - 24s 294ms/step - loss: 2.2240 - accuracy: 0.1926Crema/1049_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1007_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1086_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1081_IOM_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1001_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1038_TIE_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1075_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
#      82/Unknown - 24s 294ms/step - loss: 2.2199 - accuracy: 0.1926Crema/1008_ITH_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1029_IOM_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1072_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1008_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1089_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#      83/Unknown - 25s 294ms/step - loss: 2.2158 - accuracy: 0.1925Crema/1029_TIE_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1061_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1051_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1034_IEO_ANG_LO.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1091_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1014_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
#      84/Unknown - 25s 293ms/step - loss: 2.2118 - accuracy: 0.1926Crema/1046_ITS_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1054_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1003_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1059_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1044_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1029_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1077_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      85/Unknown - 25s 293ms/step - loss: 2.2079 - accuracy: 0.1926Crema/1023_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1060_IOM_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1030_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1036_DFA_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1079_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1010_TIE_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1010_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
#      86/Unknown - 25s 294ms/step - loss: 2.2040 - accuracy: 0.1926Crema/1016_TIE_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1071_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1015_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1042_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1020_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1028_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      87/Unknown - 26s 293ms/step - loss: 2.2003 - accuracy: 0.1926Crema/1039_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1087_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1041_IOM_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1059_TAI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1016_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1090_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
#      88/Unknown - 26s 293ms/step - loss: 2.1966 - accuracy: 0.1926Crema/1061_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1087_ITH_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1027_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1037_IEO_SAD_LO.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1062_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1084_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1084_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      89/Unknown - 26s 293ms/step - loss: 2.1930 - accuracy: 0.1926Crema/1008_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1004_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1088_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1077_TIE_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1086_IEO_HAP_LO.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1071_TIE_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1025_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
#      90/Unknown - 27s 293ms/step - loss: 2.1895 - accuracy: 0.1926Crema/1015_TIE_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1073_IEO_SAD_LO.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1051_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1015_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1061_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1017_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
#      91/Unknown - 27s 293ms/step - loss: 2.1860 - accuracy: 0.1926Crema/1058_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1035_ITH_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1011_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1045_DFA_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1083_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1071_IEO_FEA_MD.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1073_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      92/Unknown - 27s 293ms/step - loss: 2.1826 - accuracy: 0.1925Crema/1030_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1014_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1087_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1081_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1005_IEO_ANG_HI.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1065_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      93/Unknown - 27s 293ms/step - loss: 2.1792 - accuracy: 0.1925Crema/1073_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1062_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1088_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1053_ITH_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1013_ITS_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1051_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1006_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1018_ITS_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
#      94/Unknown - 28s 293ms/step - loss: 2.1759 - accuracy: 0.1925Crema/1056_WSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1024_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1050_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1089_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1048_DFA_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1016_IOM_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      95/Unknown - 28s 293ms/step - loss: 2.1727 - accuracy: 0.1924Crema/1018_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1063_IWW_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1074_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1027_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1026_IWW_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1066_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1049_ITH_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
#      96/Unknown - 28s 293ms/step - loss: 2.1696 - accuracy: 0.1924Crema/1043_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1068_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1001_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1028_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1026_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1055_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1082_IWL_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1038_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
#      97/Unknown - 29s 293ms/step - loss: 2.1665 - accuracy: 0.1924Crema/1032_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1009_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# ...
# Crema/1004_TIE_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1051_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1065_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1062_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1010_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1024_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1026_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1065_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1011_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1072_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1030_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1022_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1026_IEO_ANG_LO.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1047_IOM_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1002_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1071_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1024_TSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1041_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1028_TAI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1039_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1002_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1043_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1015_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1064_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1082_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1042_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1011_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1045_ITS_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1034_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1080_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1029_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1051_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1081_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1062_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1022_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1091_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1018_IEO_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1015_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1031_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1026_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1027_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1005_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1016_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1056_IEO_FEA_LO.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1004_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1015_ITS_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1022_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1028_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1053_TIE_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1020_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1021_IWW_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1033_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1043_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1077_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1005_TIE_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1065_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1023_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1052_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1085_IEO_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1059_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1030_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1019_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1056_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1051_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1028_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1073_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1051_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1070_ITS_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1056_TIE_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1014_IWL_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1018_IEO_ANG_LO.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1084_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1019_IEO_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1058_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1039_TAI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1074_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1026_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1049_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1002_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1038_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1030_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1072_TIE_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1018_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1032_TSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1071_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1085_IEO_SAD_MD.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1006_IEO_FEA_LO.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1065_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1089_TAI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1031_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1007_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1052_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1067_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1023_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1071_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1067_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1051_TAI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1087_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1023_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1080_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1081_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1028_WSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1076_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1043_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1007_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1024_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1035_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1019_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1028_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1023_IOM_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1081_TIE_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1084_IOM_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1070_IWW_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1016_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1007_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1028_TSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1056_TIE_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1055_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1053_ITS_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1034_MTI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1053_ITH_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1048_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1070_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1016_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1073_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1078_TAI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1028_IEO_ANG_HI.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1077_IEO_ANG_LO.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1079_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1072_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1023_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1047_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1078_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1047_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1077_TSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1049_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1018_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1005_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1062_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1083_DFA_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1057_TIE_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1034_IOM_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1068_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1046_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1048_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1015_IWL_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1033_IEO_SAD_LO.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1077_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1043_IEO_SAD_HI.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1012_DFA_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1036_WSI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1035_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1028_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1020_ITH_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1054_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1048_DFA_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1019_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1039_IWW_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1079_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1005_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1003_IEO_DIS_HI.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1006_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1053_TAI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1083_IEO_SAD_LO.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1008_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1024_IEO_HAP_HI.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1047_IEO_SAD_LO.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1019_IEO_FEA_LO.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1045_TIE_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1022_TSI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1042_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1020_WSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1026_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1065_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1075_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1031_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1068_DFA_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1023_TIE_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1006_MTI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1066_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1063_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1033_MTI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1085_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1075_MTI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1001_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1067_ITS_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1065_DFA_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1039_IEO_HAP_MD.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1089_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1038_IWW_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1005_MTI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1058_IEO_ANG_LO.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1021_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1015_ITS_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1074_TIE_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1069_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1057_IWL_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1035_TIE_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1050_TIE_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1003_ITH_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1063_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1016_IEO_ANG_MD.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1006_IEO_ANG_LO.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1010_TAI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1059_MTI_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1051_ITH_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1090_IOM_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1038_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1085_IWW_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1008_IWW_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1084_IEO_SAD_LO.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1032_WSI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1059_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1005_IEO_FEA_HI.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1056_TSI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1088_MTI_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1050_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1012_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1013_TAI_DIS_XX.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1013_IEO_DIS_LO.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1061_ITH_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1034_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1068_IEO_DIS_MD.wav tf.Tensor(3, shape=(), dtype=int64)
# Crema/1010_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1019_ITS_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1091_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1021_DFA_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1008_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1024_MTI_NEU_XX.wav tf.Tensor(4, shape=(), dtype=int64)
# Crema/1013_ITS_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1077_TSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1022_WSI_ANG_XX.wav tf.Tensor(2, shape=(), dtype=int64)
# Crema/1005_TSI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1058_ITS_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1045_IWL_FEA_XX.wav tf.Tensor(1, shape=(), dtype=int64)
# Crema/1036_IOM_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1033_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1036_IWL_HAP_XX.wav tf.Tensor(5, shape=(), dtype=int64)
# Crema/1030_TIE_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1026_TAI_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# Crema/1007_IWW_SAD_XX.wav tf.Tensor(0, shape=(), dtype=int64)
# 889/889 [==============================] - 335s 376ms/step - loss: 1.8511 - accuracy: 0.1771 - val_loss: 1.7918 - val_accuracy: 0.1741
#
# Epoch 00001: val_loss improved from inf to 1.79176, saving model to model_1/model.epoch01-loss1.79.hdf5
# Epoch 2/20
# 889/889 [==============================] - 4s 4ms/step - loss: 1.7918 - accuracy: 0.1770 - val_loss: 1.7918 - val_accuracy: 0.1741
#
# Epoch 00002: val_loss did not improve from 1.79176
# Epoch 3/20
# 889/889 [==============================] - 4s 4ms/step - loss: 1.7918 - accuracy: 0.1770 - val_loss: 1.7918 - val_accuracy: 0.1741
#
# Epoch 00003: val_loss did not improve from 1.79176
# Epoch 4/20
# 889/889 [==============================] - 4s 4ms/step - loss: 1.7918 - accuracy: 0.1770 - val_loss: 1.7918 - val_accuracy: 0.1741
#
# Epoch 00004: val_loss did not improve from 1.79176
# Epoch 5/20
# 889/889 [==============================] - 4s 4ms/step - loss: 1.7918 - accuracy: 0.1770 - val_loss: 1.7918 - val_accuracy: 0.1741
#
# Epoch 00005: val_loss did not improve from 1.79176

# %% [markdown]
# # Saving the Model

# %%
class ReduceMeanLayer(tf.keras.layers.Layer):
  def __init__(self, axis=0, **kwargs):
    super(ReduceMeanLayer, self).__init__(**kwargs)
    self.axis = axis

  def call(self, input):
    return tf.math.reduce_mean(input, axis=self.axis)

# %%
# Run the model, check the output.
scores, embeddings, spectrogram = model(wave_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v1.ipynb Cell 44 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v1.ipynb#Y111sZmlsZQ%3D%3D?line=0'>1</a> # Run the model, check the output.
# ----> <a href='vscode-notebook-cell:/Users/daniel/Documents/GitHub/pentahack/audio_classification/yamnet_v1.ipynb#Y111sZmlsZQ%3D%3D?line=1'>2</a> scores, embeddings, spectrogram = model(wave_data)
#
# NameError: name 'wave_data' is not defined

# %%
# Run the model, check the output.
scores, embeddings, spectrogram = model(waveform)
# Out:
# 2023-04-06 19:28:21.324701: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:116] None of the MLIR optimization passes are enabled (registered 2)

# %%
embeddings
# Out:
# <tf.Tensor: shape=(3, 1024), dtype=float32, numpy=
# array([[2.175924  , 0.3591828 , 0.5648943 , ..., 0.34278473, 2.2839918 ,
#         3.6191835 ],
#        [2.3264675 , 0.41704032, 0.45783436, ..., 0.33244064, 2.3892274 ,
#         3.5955532 ],
#        [2.0903363 , 0.34951845, 0.65777   , ..., 0.35120144, 2.218155  ,
#         3.730153  ]], dtype=float32)>

# %%
embeddings
# Out:
# <tf.Tensor: shape=(3, 1024), dtype=float32, numpy=
# array([[2.175924  , 0.3591828 , 0.5648943 , ..., 0.34278473, 2.2839918 ,
#         3.6191835 ],
#        [2.3264675 , 0.41704032, 0.45783436, ..., 0.33244064, 2.3892274 ,
#         3.5955532 ],
#        [2.0903363 , 0.34951845, 0.65777   , ..., 0.35120144, 2.218155  ,
#         3.730153  ]], dtype=float32)>

# %% [markdown]
# # Visualisation

# %%
plt.figure(figsize=(10, 6))

# Plot the waveform.
plt.subplot(3, 1, 1)
plt.plot(waveform)
plt.xlim([0, len(waveform)])

# Plot the log-mel spectrogram (returned by the model).
plt.subplot(3, 1, 2)
plt.imshow(spectrogram_np.T, aspect='auto', interpolation='nearest', origin='lower')

# Plot and label the model output scores for the top-scoring classes.
mean_scores = np.mean(scores, axis=0)
top_n = 10
top_class_indices = np.argsort(mean_scores)[::-1][:top_n]
plt.subplot(3, 1, 3)
plt.imshow(scores_np[:, top_class_indices].T, aspect='auto', interpolation='nearest', cmap='gray_r')

# patch_padding = (PATCH_WINDOW_SECONDS / 2) / PATCH_HOP_SECONDS
# values from the model documentation
patch_padding = (0.025 / 2) / 0.01
plt.xlim([-patch_padding-0.5, scores.shape[0] + patch_padding-0.5])
# Label the top_N classes.
yticks = range(0, top_n, 1)
plt.yticks(yticks, [class_names[top_class_indices[x]] for x in yticks])
_ = plt.ylim(-0.5 + np.array([top_n, 0]))
